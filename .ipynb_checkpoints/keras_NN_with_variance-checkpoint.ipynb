# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler

#Keras
import keras
import seaborn as sns
# import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import seaborn as sns
import tensorflow as tf
from sklearn.utils import shuffle
from sklearn.metrics import confusion_matrix

plt.style.use('ggplot')
import librosa
from librosa import feature
from librosa import display

from keras.wrappers.scikit_learn import KerasClassifier, KerasRegressor
import eli5
from eli5.sklearn import PermutationImportance

genres = [
    'blues', 'classical', 'country', 'disco', 'hiphop', 'jazz', 'metal', 'pop',
    'reggae', 'rock'
]

# %%
# load dataframe from csv
dfFeatures = pd.read_csv("music_features_updated.csv")


# extract genres for labels
genreList = dfFeatures['genre']

# drop genres and filenames for training data
dfFeatures= dfFeatures.drop(columns = ['filename', 'genre'])

dfFeatures.head()
# Out:
#    chroma_stft_mean  chroma_stft_var  spectral_centroid_mean  \
# 0          0.342053         0.089037             1782.622682
# 1          0.358000         0.090658             1364.273766
# 2          0.382027         0.087238             1521.556846
# 3          0.391765         0.094778              947.018874
# 4          0.316456         0.090731             2046.427867
#
#    spectral_centroid_var  spectral_bandwidth_mean  spectral_bandwidth_var  \
# 0          116977.082472              2020.556328            84328.680518
# 1          291346.764439              1842.030467           221553.848927
# 2          224961.620877              1736.799388            64062.188124
# 3          135762.858041              1427.836298           122599.100317
# 4          540932.742010              1858.463045           111903.623326
#
#    rolloff_mean   rolloff_var  zero_crossing_rate_mean  \
# 0   3845.075667  8.328459e+05                 0.080111
# 1   2976.303348  2.452152e+06                 0.055211
# 2   3028.062974  8.508550e+05                 0.070182
# 3   1863.946038  9.467861e+05                 0.030092
# 4   4005.025898  2.115368e+06                 0.116385
#
#    zero_crossing_rate_var  ...  mfcc16_mean  mfcc16_var  mfcc17_mean  \
# 0                0.000709  ...     0.530103   69.972038    -2.870996
# 1                0.001548  ...    -0.463962   62.798424     0.497853
# 2                0.001670  ...     2.917833   37.905025    -6.660074
# 3                0.000291  ...    -0.273013   33.782215     0.231585
# 4                0.003541  ...    -2.115260  129.746536    -8.198335
#
#    mfcc17_var  mfcc18_mean  mfcc18_var  mfcc19_mean  mfcc19_var  mfcc20_mean  \
# 0   35.479565     0.306077   43.506840    -2.700369   58.693989     2.370232
# 1   61.236259     0.039326   48.482971    -1.083576   54.454639    -0.112309
# 2   53.707203    -2.039234   48.657555    -2.045270   45.731483    -2.697336
# 3   31.175877     2.437521   30.588255     1.284240   26.782133    -2.200283
# 4   71.464584    -1.059961   62.674892    -3.900608   59.124683   -12.995133
#
#    mfcc20_var
# 0   48.047718
# 1   53.948948
# 2   28.559635
# 3   31.076508
# 4   57.077927
#
# [5 rows x 51 columns]

# %%
# standardize data  
scaler = StandardScaler()
X = scaler.fit_transform(np.array(dfFeatures.iloc[:, :-1], dtype = float))

# encode labels 
encoder = LabelEncoder()
y = encoder.fit_transform(genreList)

# split into training and test data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state = 2)
X_train, X_val, y_train, y_val  = train_test_split(X_train, y_train, test_size=0.25, random_state=2)

# %%
# initialize keras network
model = keras.Sequential()
model.add(keras.layers.Dense(256, activation='relu', input_shape=(X_train.shape[1],)))
model.add(keras.layers.Dense(128, activation='relu'))
model.add(keras.layers.Dense(64, activation='relu'))
model.add(keras.layers.Dense(10, activation='softmax'))

# %%
# configure model for training
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
# train model

# https://www.geeksforgeeks.org/choose-optimal-number-of-epochs-to-train-a-neural-network-in-keras/
from keras import callbacks

#callback to prevent overfitting
earlystopping = callbacks.EarlyStopping(monitor ="val_loss", 
                                        mode ="min", patience = 10, 
                                        restore_best_weights = True)


history = model.fit(X_train,
                    y_train,
                    validation_data=(X_val, y_val),
                    epochs=100,
                    batch_size=128,
                    callbacks =[earlystopping])
# Out:
# Epoch 1/100
# 5/5 [==============================] - 2s 285ms/step - loss: 2.2574 - accuracy: 0.1362 - val_loss: 2.0269 - val_accuracy: 0.3150
# Epoch 2/100
# 5/5 [==============================] - 0s 12ms/step - loss: 1.9526 - accuracy: 0.3744 - val_loss: 1.8191 - val_accuracy: 0.3900
# Epoch 3/100
# 5/5 [==============================] - 0s 15ms/step - loss: 1.7364 - accuracy: 0.4600 - val_loss: 1.6479 - val_accuracy: 0.3950
# Epoch 4/100
# 5/5 [==============================] - 0s 18ms/step - loss: 1.5074 - accuracy: 0.4971 - val_loss: 1.5158 - val_accuracy: 0.4450
# Epoch 5/100
# 5/5 [==============================] - 0s 13ms/step - loss: 1.3495 - accuracy: 0.5539 - val_loss: 1.3906 - val_accuracy: 0.4800
# Epoch 6/100
# 5/5 [==============================] - 0s 12ms/step - loss: 1.1891 - accuracy: 0.6132 - val_loss: 1.2642 - val_accuracy: 0.5400
# Epoch 7/100
# 5/5 [==============================] - 0s 12ms/step - loss: 1.0362 - accuracy: 0.6908 - val_loss: 1.1708 - val_accuracy: 0.5700
# Epoch 8/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.9859 - accuracy: 0.6815 - val_loss: 1.1092 - val_accuracy: 0.6200
# Epoch 9/100
# 5/5 [==============================] - 0s 12ms/step - loss: 0.8819 - accuracy: 0.7308 - val_loss: 1.0772 - val_accuracy: 0.6050
# Epoch 10/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.7772 - accuracy: 0.7506 - val_loss: 1.0290 - val_accuracy: 0.6650
# Epoch 11/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.7072 - accuracy: 0.8014 - val_loss: 1.0247 - val_accuracy: 0.6650
# Epoch 12/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.6450 - accuracy: 0.8160 - val_loss: 0.9900 - val_accuracy: 0.6550
# Epoch 13/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.5846 - accuracy: 0.8382 - val_loss: 0.9781 - val_accuracy: 0.6700
# Epoch 14/100
# 5/5 [==============================] - 0s 12ms/step - loss: 0.5350 - accuracy: 0.8518 - val_loss: 0.9686 - val_accuracy: 0.6850
# Epoch 15/100
# 5/5 [==============================] - 0s 12ms/step - loss: 0.4869 - accuracy: 0.8586 - val_loss: 0.9610 - val_accuracy: 0.7000
# Epoch 16/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.4411 - accuracy: 0.8775 - val_loss: 0.9634 - val_accuracy: 0.6600
# Epoch 17/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.3924 - accuracy: 0.9106 - val_loss: 0.9373 - val_accuracy: 0.6950
# Epoch 18/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.3526 - accuracy: 0.9166 - val_loss: 0.9755 - val_accuracy: 0.6600
# Epoch 19/100
# 5/5 [==============================] - 0s 12ms/step - loss: 0.3254 - accuracy: 0.9319 - val_loss: 0.9546 - val_accuracy: 0.6900
# Epoch 20/100
# 5/5 [==============================] - 0s 11ms/step - loss: 0.2930 - accuracy: 0.9373 - val_loss: 0.9475 - val_accuracy: 0.6600
# Epoch 21/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.2525 - accuracy: 0.9526 - val_loss: 0.9832 - val_accuracy: 0.6650
# Epoch 22/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.2454 - accuracy: 0.9676 - val_loss: 0.9535 - val_accuracy: 0.6950
# Epoch 23/100
# 5/5 [==============================] - 0s 16ms/step - loss: 0.2300 - accuracy: 0.9594 - val_loss: 0.9768 - val_accuracy: 0.6550
# Epoch 24/100
# 5/5 [==============================] - 0s 17ms/step - loss: 0.1984 - accuracy: 0.9694 - val_loss: 0.9719 - val_accuracy: 0.6700
# Epoch 25/100
# 5/5 [==============================] - 0s 11ms/step - loss: 0.1663 - accuracy: 0.9804 - val_loss: 0.9898 - val_accuracy: 0.6700
# Epoch 26/100
# 5/5 [==============================] - 0s 11ms/step - loss: 0.1587 - accuracy: 0.9858 - val_loss: 1.0012 - val_accuracy: 0.6700
# Epoch 27/100
# 5/5 [==============================] - 0s 12ms/step - loss: 0.1464 - accuracy: 0.9909 - val_loss: 0.9941 - val_accuracy: 0.6550

# %%
test_loss, test_acc  = model.evaluate(X_test, y_test, batch_size=128)
# Out:
# 2/2 [==============================] - 0s 2ms/step - loss: 0.8700 - accuracy: 0.6750

# %%
prediction = model.predict(X_test)
y_pred = []
for index, y_encode in enumerate(prediction):
    y_pred.append(np.argmax(y_encode))
corrMatrix = confusion_matrix(y_test, y_pred)
fig, ax = plt.subplots(figsize=(10,10))

sns.heatmap(corrMatrix, annot = True, xticklabels=genres, yticklabels=genres, cbar=False).set_title("Confusion Matrix: Base Model")
# Out:
# Text(0.5, 1.0, 'Confusion Matrix: Base Model')

# %%
fig, ax = plt.subplots(1,2,figsize=(30,15))

ax[0].plot(history.history['accuracy'])
ax[0].plot(history.history['val_accuracy'])
ax[1].plot(history.history['loss'])
ax[1].plot(history.history['val_loss'])
ax[0].legend(["Accuracy", "Validation Accuracy"])
ax[1].legend(["Loss", "Validation Loss"])
ax[0].set_ylabel("Accuracy")
ax[0].set_xlabel("Epoch")
ax[0].set_title("Dataset 2: Base Model: Accuracy")
ax[1].set_title("Dataset 2: Base Model: Loss")
ax[1].set_ylabel("Loss")
ax[1].set_xlabel("Epoch")
# Out:
# Text(0.5, 0, 'Epoch')

# %%
# initialize keras network
modeldropout = keras.Sequential()
modeldropout.add(keras.layers.Dense(256, activation='relu', input_shape=(X_train.shape[1],)))
modeldropout.add(keras.layers.Dropout(0.2))
modeldropout.add(keras.layers.Dense(128, activation='relu'))
modeldropout.add(keras.layers.Dropout(0.2))
modeldropout.add(keras.layers.Dense(64, activation='relu'))
modeldropout.add(keras.layers.Dropout(0.2))
modeldropout.add(keras.layers.Dense(10, activation='softmax'))

# %%
modeldropout.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
history = modeldropout.fit(X_train,
                    y_train,
                    epochs=100,
                    callbacks =[earlystopping],
                    validation_data=(X_val, y_val),
                    batch_size=128)
# Out:
# Epoch 1/100
# 5/5 [==============================] - 1s 121ms/step - loss: 2.3501 - accuracy: 0.1283 - val_loss: 2.1299 - val_accuracy: 0.3000
# Epoch 2/100
# 5/5 [==============================] - 0s 17ms/step - loss: 2.1197 - accuracy: 0.2707 - val_loss: 1.9686 - val_accuracy: 0.3700
# Epoch 3/100
# 5/5 [==============================] - 0s 14ms/step - loss: 1.9414 - accuracy: 0.3634 - val_loss: 1.8231 - val_accuracy: 0.3850
# Epoch 4/100
# 5/5 [==============================] - 0s 12ms/step - loss: 1.8143 - accuracy: 0.3877 - val_loss: 1.6861 - val_accuracy: 0.4000
# Epoch 5/100
# 5/5 [==============================] - 0s 16ms/step - loss: 1.6221 - accuracy: 0.4399 - val_loss: 1.5399 - val_accuracy: 0.4400
# Epoch 6/100
# 5/5 [==============================] - 0s 20ms/step - loss: 1.5582 - accuracy: 0.4619 - val_loss: 1.4171 - val_accuracy: 0.4700
# Epoch 7/100
# 5/5 [==============================] - 0s 15ms/step - loss: 1.4684 - accuracy: 0.4685 - val_loss: 1.3332 - val_accuracy: 0.4800
# Epoch 8/100
# 5/5 [==============================] - 0s 14ms/step - loss: 1.3789 - accuracy: 0.5098 - val_loss: 1.2753 - val_accuracy: 0.4750
# Epoch 9/100
# 5/5 [==============================] - 0s 15ms/step - loss: 1.2640 - accuracy: 0.5519 - val_loss: 1.2227 - val_accuracy: 0.4900
# Epoch 10/100
# 5/5 [==============================] - 0s 11ms/step - loss: 1.2756 - accuracy: 0.5101 - val_loss: 1.1543 - val_accuracy: 0.5350
# Epoch 11/100
# 5/5 [==============================] - 0s 15ms/step - loss: 1.1570 - accuracy: 0.6060 - val_loss: 1.1246 - val_accuracy: 0.5700
# Epoch 12/100
# 5/5 [==============================] - 0s 16ms/step - loss: 1.1287 - accuracy: 0.5946 - val_loss: 1.0941 - val_accuracy: 0.5850
# Epoch 13/100
# 5/5 [==============================] - 0s 14ms/step - loss: 1.0651 - accuracy: 0.6229 - val_loss: 1.0815 - val_accuracy: 0.5750
# Epoch 14/100
# 5/5 [==============================] - 0s 12ms/step - loss: 1.0443 - accuracy: 0.6449 - val_loss: 1.0647 - val_accuracy: 0.5800
# Epoch 15/100
# 5/5 [==============================] - 0s 12ms/step - loss: 0.9572 - accuracy: 0.6577 - val_loss: 1.0447 - val_accuracy: 0.5950
# Epoch 16/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.9117 - accuracy: 0.6770 - val_loss: 1.0168 - val_accuracy: 0.6050
# Epoch 17/100
# 5/5 [==============================] - 0s 18ms/step - loss: 0.8665 - accuracy: 0.6969 - val_loss: 1.0064 - val_accuracy: 0.5950
# Epoch 18/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.8829 - accuracy: 0.6965 - val_loss: 1.0023 - val_accuracy: 0.6100
# Epoch 19/100
# 5/5 [==============================] - 0s 12ms/step - loss: 0.8090 - accuracy: 0.7023 - val_loss: 0.9946 - val_accuracy: 0.6100
# Epoch 20/100
# 5/5 [==============================] - 0s 12ms/step - loss: 0.8117 - accuracy: 0.7460 - val_loss: 0.9641 - val_accuracy: 0.6200
# Epoch 21/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.7316 - accuracy: 0.7691 - val_loss: 0.9498 - val_accuracy: 0.6250
# Epoch 22/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.7627 - accuracy: 0.7197 - val_loss: 0.9453 - val_accuracy: 0.6300
# Epoch 23/100
# 5/5 [==============================] - 0s 12ms/step - loss: 0.7620 - accuracy: 0.7319 - val_loss: 0.9421 - val_accuracy: 0.6000
# Epoch 24/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.7511 - accuracy: 0.7231 - val_loss: 0.9389 - val_accuracy: 0.6200
# Epoch 25/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.6599 - accuracy: 0.7795 - val_loss: 0.9312 - val_accuracy: 0.6350
# Epoch 26/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.6583 - accuracy: 0.7676 - val_loss: 0.9576 - val_accuracy: 0.6350
# Epoch 27/100
# 5/5 [==============================] - 0s 18ms/step - loss: 0.6451 - accuracy: 0.7789 - val_loss: 0.9563 - val_accuracy: 0.6200
# Epoch 28/100
# 5/5 [==============================] - 0s 21ms/step - loss: 0.6420 - accuracy: 0.7571 - val_loss: 0.9424 - val_accuracy: 0.6400
# Epoch 29/100
# 5/5 [==============================] - 0s 19ms/step - loss: 0.5903 - accuracy: 0.8085 - val_loss: 0.9540 - val_accuracy: 0.6100
# Epoch 30/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.6235 - accuracy: 0.7777 - val_loss: 0.9386 - val_accuracy: 0.6200
# Epoch 31/100
# 5/5 [==============================] - 0s 18ms/step - loss: 0.5229 - accuracy: 0.8360 - val_loss: 0.9244 - val_accuracy: 0.6600
# Epoch 32/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.5244 - accuracy: 0.8306 - val_loss: 0.9686 - val_accuracy: 0.6100
# Epoch 33/100
# 5/5 [==============================] - 0s 20ms/step - loss: 0.5341 - accuracy: 0.7985 - val_loss: 0.9669 - val_accuracy: 0.6150
# Epoch 34/100
# 5/5 [==============================] - 0s 19ms/step - loss: 0.5299 - accuracy: 0.8311 - val_loss: 0.9605 - val_accuracy: 0.6300
# Epoch 35/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.5036 - accuracy: 0.8249 - val_loss: 0.9351 - val_accuracy: 0.6450
# Epoch 36/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.4853 - accuracy: 0.8383 - val_loss: 0.9326 - val_accuracy: 0.6500
# Epoch 37/100
# 5/5 [==============================] - 0s 17ms/step - loss: 0.4760 - accuracy: 0.8256 - val_loss: 0.9387 - val_accuracy: 0.6400
# Epoch 38/100
# 5/5 [==============================] - 0s 17ms/step - loss: 0.4663 - accuracy: 0.8407 - val_loss: 0.9577 - val_accuracy: 0.6400
# Epoch 39/100
# 5/5 [==============================] - 0s 17ms/step - loss: 0.4097 - accuracy: 0.8754 - val_loss: 0.9615 - val_accuracy: 0.6550
# Epoch 40/100
# 5/5 [==============================] - 0s 17ms/step - loss: 0.4201 - accuracy: 0.8583 - val_loss: 0.9328 - val_accuracy: 0.6700
# Epoch 41/100
# 5/5 [==============================] - 0s 18ms/step - loss: 0.4345 - accuracy: 0.8544 - val_loss: 0.9204 - val_accuracy: 0.7050
# Epoch 42/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.3835 - accuracy: 0.8655 - val_loss: 0.9872 - val_accuracy: 0.6300
# Epoch 43/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.3695 - accuracy: 0.8760 - val_loss: 1.0080 - val_accuracy: 0.6200
# Epoch 44/100
# 5/5 [==============================] - 0s 16ms/step - loss: 0.3804 - accuracy: 0.8721 - val_loss: 0.9708 - val_accuracy: 0.6450
# Epoch 45/100
# 5/5 [==============================] - 0s 16ms/step - loss: 0.3926 - accuracy: 0.8565 - val_loss: 0.9696 - val_accuracy: 0.6550
# Epoch 46/100
# 5/5 [==============================] - 0s 16ms/step - loss: 0.3349 - accuracy: 0.8897 - val_loss: 0.9892 - val_accuracy: 0.6450
# Epoch 47/100
# 5/5 [==============================] - 0s 27ms/step - loss: 0.3602 - accuracy: 0.8794 - val_loss: 1.0027 - val_accuracy: 0.6550
# Epoch 48/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.3195 - accuracy: 0.9211 - val_loss: 1.0132 - val_accuracy: 0.6500
# Epoch 49/100
# 5/5 [==============================] - 0s 16ms/step - loss: 0.3189 - accuracy: 0.9015 - val_loss: 1.0187 - val_accuracy: 0.6650
# Epoch 50/100
# 5/5 [==============================] - 0s 18ms/step - loss: 0.3359 - accuracy: 0.8781 - val_loss: 1.0200 - val_accuracy: 0.6250
# Epoch 51/100
# 5/5 [==============================] - 0s 17ms/step - loss: 0.2823 - accuracy: 0.9002 - val_loss: 1.0129 - val_accuracy: 0.6350

# %%
test_loss, test_acc  = modeldropout.evaluate(X_test, y_test, batch_size=128)
# Out:
# 2/2 [==============================] - 0s 4ms/step - loss: 0.9545 - accuracy: 0.6750

# %%
prediction = modeldropout.predict(X_test)
y_pred = []
for index, y_encode in enumerate(prediction):
    y_pred.append(np.argmax(y_encode))
corrMatrix = confusion_matrix(y_test, y_pred)
fig, ax = plt.subplots(figsize=(10,10))

sns.heatmap(corrMatrix, annot = True, xticklabels=genres, yticklabels=genres, cbar=False).set_title("Confusion Matrix: Model w/ Dropout")
# Out:
# Text(0.5, 1.0, 'Confusion Matrix: Model w/ Dropout')

# %%
fig, ax = plt.subplots(1,2,figsize=(30,15))

ax[0].plot(history.history['accuracy'])
ax[0].plot(history.history['val_accuracy'])
ax[1].plot(history.history['loss'])
ax[1].plot(history.history['val_loss'])
ax[0].legend(["Accuracy", "Validation Accuracy"])
ax[1].legend(["Loss", "Validation Loss"])
ax[0].set_ylabel("Accuracy")
ax[0].set_xlabel("Epoch")
ax[0].set_title("Dataset 2: Model with Dropout: Accuracy")
ax[1].set_title("Dataset 2: Model with Dropout: Loss")
ax[1].set_ylabel("Loss")
ax[1].set_xlabel("Epoch")
# Out:
# Text(0.5, 0, 'Epoch')

# %%
modelReg = keras.Sequential()
modelReg.add(keras.layers.Dense(256, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(1e-4), input_shape=(X_train.shape[1],)))
modelReg.add(keras.layers.Dropout(0.2))
modelReg.add(keras.layers.Dense(128, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(1e-4)))
modelReg.add(keras.layers.Dropout(0.2))
modelReg.add(keras.layers.Dense(64, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(1e-4)))
modelReg.add(keras.layers.Dropout(0.2))
modelReg.add(keras.layers.Dense(10, activation='softmax', activity_regularizer=tf.keras.regularizers.l2(1e-4)))

modelReg.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
history = modelReg.fit(X_train,
                    y_train,
                    epochs=100,
                    callbacks =[earlystopping],
                    validation_data=(X_val, y_val),
                    batch_size=128)
# Out:
# Epoch 1/100
# 5/5 [==============================] - 1s 67ms/step - loss: 2.4534 - accuracy: 0.1105 - val_loss: 2.2037 - val_accuracy: 0.3150
# Epoch 2/100
# 5/5 [==============================] - 0s 14ms/step - loss: 2.1806 - accuracy: 0.2493 - val_loss: 2.0733 - val_accuracy: 0.3650
# Epoch 3/100
# 5/5 [==============================] - 0s 13ms/step - loss: 2.0125 - accuracy: 0.3688 - val_loss: 1.9511 - val_accuracy: 0.3600
# Epoch 4/100
# 5/5 [==============================] - 0s 14ms/step - loss: 1.9040 - accuracy: 0.3812 - val_loss: 1.8207 - val_accuracy: 0.4000
# Epoch 5/100
# 5/5 [==============================] - 0s 15ms/step - loss: 1.8030 - accuracy: 0.4105 - val_loss: 1.6723 - val_accuracy: 0.4250
# Epoch 6/100
# 5/5 [==============================] - 0s 15ms/step - loss: 1.6605 - accuracy: 0.4418 - val_loss: 1.5444 - val_accuracy: 0.4650
# Epoch 7/100
# 5/5 [==============================] - 0s 15ms/step - loss: 1.5734 - accuracy: 0.4585 - val_loss: 1.4630 - val_accuracy: 0.4850
# Epoch 8/100
# 5/5 [==============================] - 0s 16ms/step - loss: 1.4917 - accuracy: 0.4792 - val_loss: 1.3890 - val_accuracy: 0.4850
# Epoch 9/100
# 5/5 [==============================] - 0s 16ms/step - loss: 1.4152 - accuracy: 0.5402 - val_loss: 1.3131 - val_accuracy: 0.5050
# Epoch 10/100
# 5/5 [==============================] - 0s 18ms/step - loss: 1.3456 - accuracy: 0.5508 - val_loss: 1.2638 - val_accuracy: 0.5250
# Epoch 11/100
# 5/5 [==============================] - 0s 17ms/step - loss: 1.2866 - accuracy: 0.5830 - val_loss: 1.2108 - val_accuracy: 0.5550
# Epoch 12/100
# 5/5 [==============================] - 0s 14ms/step - loss: 1.1764 - accuracy: 0.5985 - val_loss: 1.1821 - val_accuracy: 0.5500
# Epoch 13/100
# 5/5 [==============================] - 0s 14ms/step - loss: 1.1443 - accuracy: 0.6105 - val_loss: 1.1426 - val_accuracy: 0.5600
# Epoch 14/100
# 5/5 [==============================] - 0s 13ms/step - loss: 1.1468 - accuracy: 0.6219 - val_loss: 1.1283 - val_accuracy: 0.5650
# Epoch 15/100
# 5/5 [==============================] - 0s 15ms/step - loss: 1.0812 - accuracy: 0.6529 - val_loss: 1.1101 - val_accuracy: 0.5800
# Epoch 16/100
# 5/5 [==============================] - 0s 18ms/step - loss: 1.0457 - accuracy: 0.6537 - val_loss: 1.0735 - val_accuracy: 0.5950
# Epoch 17/100
# 5/5 [==============================] - 0s 20ms/step - loss: 0.9927 - accuracy: 0.6747 - val_loss: 1.0600 - val_accuracy: 0.5950
# Epoch 18/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.9473 - accuracy: 0.6712 - val_loss: 1.0462 - val_accuracy: 0.5950
# Epoch 19/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.9422 - accuracy: 0.6914 - val_loss: 1.0569 - val_accuracy: 0.6050
# Epoch 20/100
# 5/5 [==============================] - 0s 20ms/step - loss: 0.8976 - accuracy: 0.7045 - val_loss: 1.0482 - val_accuracy: 0.6150
# Epoch 21/100
# 5/5 [==============================] - 0s 12ms/step - loss: 0.9574 - accuracy: 0.6775 - val_loss: 1.0435 - val_accuracy: 0.6100
# Epoch 22/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.8816 - accuracy: 0.7164 - val_loss: 1.0297 - val_accuracy: 0.6100
# Epoch 23/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.8155 - accuracy: 0.7361 - val_loss: 0.9882 - val_accuracy: 0.6700
# Epoch 24/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.7776 - accuracy: 0.7387 - val_loss: 1.0021 - val_accuracy: 0.6300
# Epoch 25/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.7509 - accuracy: 0.7454 - val_loss: 1.0145 - val_accuracy: 0.6000
# Epoch 26/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.7218 - accuracy: 0.7665 - val_loss: 0.9840 - val_accuracy: 0.6700
# Epoch 27/100
# 5/5 [==============================] - 0s 16ms/step - loss: 0.7319 - accuracy: 0.7612 - val_loss: 0.9805 - val_accuracy: 0.6650
# Epoch 28/100
# 5/5 [==============================] - 0s 16ms/step - loss: 0.7608 - accuracy: 0.7631 - val_loss: 0.9780 - val_accuracy: 0.6700
# Epoch 29/100
# 5/5 [==============================] - 0s 16ms/step - loss: 0.6602 - accuracy: 0.8028 - val_loss: 0.9697 - val_accuracy: 0.6650
# Epoch 30/100
# 5/5 [==============================] - 0s 16ms/step - loss: 0.6673 - accuracy: 0.7858 - val_loss: 0.9770 - val_accuracy: 0.6700
# Epoch 31/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.6468 - accuracy: 0.7836 - val_loss: 0.9973 - val_accuracy: 0.6850
# Epoch 32/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.6238 - accuracy: 0.7954 - val_loss: 0.9848 - val_accuracy: 0.6550
# Epoch 33/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.5915 - accuracy: 0.8226 - val_loss: 0.9858 - val_accuracy: 0.6450
# Epoch 34/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.5149 - accuracy: 0.8544 - val_loss: 0.9706 - val_accuracy: 0.6600
# Epoch 35/100
# 5/5 [==============================] - ETA: 0s - loss: 0.5745 - accuracy: 0.82 - 0s 16ms/step - loss: 0.5659 - accuracy: 0.8144 - val_loss: 0.9780 - val_accuracy: 0.6750
# Epoch 36/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.5360 - accuracy: 0.8405 - val_loss: 0.9749 - val_accuracy: 0.6900
# Epoch 37/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.5238 - accuracy: 0.8381 - val_loss: 0.9640 - val_accuracy: 0.6900
# Epoch 38/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.5333 - accuracy: 0.8493 - val_loss: 0.9727 - val_accuracy: 0.6750
# Epoch 39/100
# 5/5 [==============================] - 0s 16ms/step - loss: 0.4911 - accuracy: 0.8430 - val_loss: 0.9722 - val_accuracy: 0.6750
# Epoch 40/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.4936 - accuracy: 0.8552 - val_loss: 1.0098 - val_accuracy: 0.6800
# Epoch 41/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.5133 - accuracy: 0.8459 - val_loss: 1.0151 - val_accuracy: 0.6700
# Epoch 42/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.4470 - accuracy: 0.8906 - val_loss: 1.0123 - val_accuracy: 0.6850
# Epoch 43/100
# 5/5 [==============================] - 0s 16ms/step - loss: 0.4207 - accuracy: 0.8684 - val_loss: 1.0024 - val_accuracy: 0.6800
# Epoch 44/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.4518 - accuracy: 0.8632 - val_loss: 0.9963 - val_accuracy: 0.6900
# Epoch 45/100
# 5/5 [==============================] - 0s 12ms/step - loss: 0.3971 - accuracy: 0.8899 - val_loss: 1.0036 - val_accuracy: 0.6800
# Epoch 46/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.3969 - accuracy: 0.8781 - val_loss: 1.0349 - val_accuracy: 0.6900
# Epoch 47/100
# 5/5 [==============================] - 0s 16ms/step - loss: 0.4041 - accuracy: 0.9026 - val_loss: 1.0258 - val_accuracy: 0.6950

# %%
test_loss, test_acc  = modelReg.evaluate(X_test, y_test, batch_size=128)
# Out:
# 2/2 [==============================] - 0s 3ms/step - loss: 0.9964 - accuracy: 0.6950

# %%
prediction = modelReg.predict(X_test)
y_pred = []
for index, y_encode in enumerate(prediction):
    y_pred.append(np.argmax(y_encode))
corrMatrix = confusion_matrix(y_test, y_pred)
fig, ax = plt.subplots(figsize=(10,10))

sns.heatmap(corrMatrix, annot = True, xticklabels=genres, yticklabels=genres, cbar=False).set_title("Dataset 2: Confusion Matrix: Model w/ Dropout and Reg")
# Out:
# Text(0.5, 1.0, 'Confusion Matrix: Model w/ Dropout and Reg')

# %%
fig, ax = plt.subplots(1,2,figsize=(30,15))

ax[0].plot(history.history['accuracy'])
ax[0].plot(history.history['val_accuracy'])
ax[1].plot(history.history['loss'])
ax[1].plot(history.history['val_loss'])
ax[0].legend(["Accuracy", "Validation Accuracy"])
ax[1].legend(["Loss", "Validation Loss"])
ax[0].set_ylabel("Accuracy")
ax[0].set_xlabel("Epoch")
ax[0].set_title("Dataset 2: Model with Dropout and Reg: Accuracy")
ax[1].set_title("Dataset 2: Model with Dropout and Reg: Loss")
ax[1].set_ylabel("Loss")
ax[1].set_xlabel("Epoch")
# Out:
# Text(0.5, 0, 'Epoch')
