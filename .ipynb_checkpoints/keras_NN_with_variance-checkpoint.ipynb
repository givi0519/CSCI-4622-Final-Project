# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler

#Keras
import keras
import seaborn as sns
# import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import seaborn as sns
import tensorflow as tf
from sklearn.utils import shuffle
from sklearn.metrics import confusion_matrix

plt.style.use('ggplot')
import librosa
from librosa import feature
from librosa import display
genres = [
    'blues', 'classical', 'country', 'disco', 'hiphop', 'jazz', 'metal', 'pop',
    'reggae', 'rock'
]

# %%
# load dataframe from csv
dfFeatures = pd.read_csv("music_features_updated.csv")


# extract genres for labels
genreList = dfFeatures['genre']

# drop genres and filenames for training data
dfFeatures= dfFeatures.drop(columns = ['filename', 'genre'])

dfFeatures.head()
# Out:
#    chroma_stft_mean  chroma_stft_var  spectral_centroid_mean  \
# 0          0.342053         0.089037             1782.622682
# 1          0.358000         0.090658             1364.273766
# 2          0.382027         0.087238             1521.556846
# 3          0.391765         0.094778              947.018874
# 4          0.316456         0.090731             2046.427867
#
#    spectral_centroid_var  spectral_bandwidth_mean  spectral_bandwidth_var  \
# 0          116977.082472              2020.556328            84328.680518
# 1          291346.764439              1842.030467           221553.848927
# 2          224961.620877              1736.799388            64062.188124
# 3          135762.858041              1427.836298           122599.100317
# 4          540932.742010              1858.463045           111903.623326
#
#    rolloff_mean   rolloff_var  zero_crossing_rate_mean  \
# 0   3845.075667  8.328459e+05                 0.080111
# 1   2976.303348  2.452152e+06                 0.055211
# 2   3028.062974  8.508550e+05                 0.070182
# 3   1863.946038  9.467861e+05                 0.030092
# 4   4005.025898  2.115368e+06                 0.116385
#
#    zero_crossing_rate_var  ...  mfcc16_mean  mfcc16_var  mfcc17_mean  \
# 0                0.000709  ...     0.530103   69.972038    -2.870996
# 1                0.001548  ...    -0.463962   62.798424     0.497853
# 2                0.001670  ...     2.917833   37.905025    -6.660074
# 3                0.000291  ...    -0.273013   33.782215     0.231585
# 4                0.003541  ...    -2.115260  129.746536    -8.198335
#
#    mfcc17_var  mfcc18_mean  mfcc18_var  mfcc19_mean  mfcc19_var  mfcc20_mean  \
# 0   35.479565     0.306077   43.506840    -2.700369   58.693989     2.370232
# 1   61.236259     0.039326   48.482971    -1.083576   54.454639    -0.112309
# 2   53.707203    -2.039234   48.657555    -2.045270   45.731483    -2.697336
# 3   31.175877     2.437521   30.588255     1.284240   26.782133    -2.200283
# 4   71.464584    -1.059961   62.674892    -3.900608   59.124683   -12.995133
#
#    mfcc20_var
# 0   48.047718
# 1   53.948948
# 2   28.559635
# 3   31.076508
# 4   57.077927
#
# [5 rows x 51 columns]

# %%
# standardize data  
scaler = StandardScaler()
X = scaler.fit_transform(np.array(dfFeatures.iloc[:, :-1], dtype = float))

# encode labels 
encoder = LabelEncoder()
y = encoder.fit_transform(genreList)

# split into training and test data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state = 2)
X_train, X_val, y_train, y_val  = train_test_split(X_train, y_train, test_size=0.20, random_state=2)

# %%
# initialize keras network
model = keras.Sequential()
model.add(keras.layers.Dense(256, activation='relu', input_shape=(X_train.shape[1],)))
model.add(keras.layers.Dense(128, activation='relu'))
model.add(keras.layers.Dense(64, activation='relu'))
model.add(keras.layers.Dense(10, activation='softmax'))

# %%
# configure model for training
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
# train model

# https://www.geeksforgeeks.org/choose-optimal-number-of-epochs-to-train-a-neural-network-in-keras/
from keras import callbacks

#callback to prevent overfitting
earlystopping = callbacks.EarlyStopping(monitor ="val_loss", 
                                        mode ="min", patience = 10, 
                                        restore_best_weights = True)


history = model.fit(X_train,
                    y_train,
                    validation_data=(X_val, y_val),
                    epochs=40,
                    batch_size=128,
                    callbacks =[earlystopping])
# Out:
# Epoch 1/40
# 5/5 [==============================] - 2s 295ms/step - loss: 2.2561 - accuracy: 0.1439 - val_loss: 2.0171 - val_accuracy: 0.3375
# Epoch 2/40
# 5/5 [==============================] - 0s 13ms/step - loss: 1.9664 - accuracy: 0.3809 - val_loss: 1.8141 - val_accuracy: 0.3688
# Epoch 3/40
# 5/5 [==============================] - 0s 15ms/step - loss: 1.7031 - accuracy: 0.4550 - val_loss: 1.6375 - val_accuracy: 0.4000
# Epoch 4/40
# 5/5 [==============================] - 0s 14ms/step - loss: 1.4882 - accuracy: 0.5379 - val_loss: 1.4821 - val_accuracy: 0.4437
# Epoch 5/40
# 5/5 [==============================] - 0s 12ms/step - loss: 1.3047 - accuracy: 0.5599 - val_loss: 1.3733 - val_accuracy: 0.4625
# Epoch 6/40
# 5/5 [==============================] - 0s 14ms/step - loss: 1.1484 - accuracy: 0.6152 - val_loss: 1.2645 - val_accuracy: 0.5188
# Epoch 7/40
# 5/5 [==============================] - 0s 15ms/step - loss: 1.0278 - accuracy: 0.6471 - val_loss: 1.1965 - val_accuracy: 0.5625
# Epoch 8/40
# 5/5 [==============================] - 0s 17ms/step - loss: 0.9095 - accuracy: 0.6919 - val_loss: 1.1549 - val_accuracy: 0.5813
# Epoch 9/40
# 5/5 [==============================] - 0s 14ms/step - loss: 0.8474 - accuracy: 0.7153 - val_loss: 1.1126 - val_accuracy: 0.6375
# Epoch 10/40
# 5/5 [==============================] - 0s 14ms/step - loss: 0.7393 - accuracy: 0.7520 - val_loss: 1.1165 - val_accuracy: 0.6062
# Epoch 11/40
# 5/5 [==============================] - 0s 16ms/step - loss: 0.7042 - accuracy: 0.7910 - val_loss: 1.0375 - val_accuracy: 0.6625
# Epoch 12/40
# 5/5 [==============================] - 0s 18ms/step - loss: 0.6207 - accuracy: 0.8118 - val_loss: 1.0342 - val_accuracy: 0.6187
# Epoch 13/40
# 5/5 [==============================] - 0s 12ms/step - loss: 0.5778 - accuracy: 0.8181 - val_loss: 1.0335 - val_accuracy: 0.6625
# Epoch 14/40
# 5/5 [==============================] - 0s 14ms/step - loss: 0.5265 - accuracy: 0.8575 - val_loss: 1.0017 - val_accuracy: 0.6625
# Epoch 15/40
# 5/5 [==============================] - 0s 16ms/step - loss: 0.4931 - accuracy: 0.8586 - val_loss: 0.9777 - val_accuracy: 0.6812
# Epoch 16/40
# 5/5 [==============================] - 0s 15ms/step - loss: 0.4262 - accuracy: 0.8961 - val_loss: 0.9738 - val_accuracy: 0.7000
# Epoch 17/40
# 5/5 [==============================] - 0s 16ms/step - loss: 0.4027 - accuracy: 0.8976 - val_loss: 0.9714 - val_accuracy: 0.6812
# Epoch 18/40
# 5/5 [==============================] - 0s 13ms/step - loss: 0.3598 - accuracy: 0.9146 - val_loss: 0.9594 - val_accuracy: 0.7063
# Epoch 19/40
# 5/5 [==============================] - 0s 16ms/step - loss: 0.3381 - accuracy: 0.9104 - val_loss: 0.9721 - val_accuracy: 0.6812
# Epoch 20/40
# 5/5 [==============================] - 0s 13ms/step - loss: 0.3077 - accuracy: 0.9373 - val_loss: 0.9494 - val_accuracy: 0.6875
# Epoch 21/40
# 5/5 [==============================] - 0s 14ms/step - loss: 0.2872 - accuracy: 0.9479 - val_loss: 0.9733 - val_accuracy: 0.6687
# Epoch 22/40
# 5/5 [==============================] - 0s 14ms/step - loss: 0.2600 - accuracy: 0.9520 - val_loss: 0.9575 - val_accuracy: 0.6875
# Epoch 23/40
# 5/5 [==============================] - 0s 14ms/step - loss: 0.2267 - accuracy: 0.9667 - val_loss: 0.9935 - val_accuracy: 0.6812
# Epoch 24/40
# 5/5 [==============================] - 0s 13ms/step - loss: 0.2047 - accuracy: 0.9687 - val_loss: 0.9868 - val_accuracy: 0.6875
# Epoch 25/40
# 5/5 [==============================] - 0s 14ms/step - loss: 0.1736 - accuracy: 0.9806 - val_loss: 0.9687 - val_accuracy: 0.6938
# Epoch 26/40
# 5/5 [==============================] - 0s 16ms/step - loss: 0.1706 - accuracy: 0.9811 - val_loss: 1.0190 - val_accuracy: 0.7063
# Epoch 27/40
# 5/5 [==============================] - 0s 18ms/step - loss: 0.1536 - accuracy: 0.9835 - val_loss: 1.0136 - val_accuracy: 0.7063
# Epoch 28/40
# 5/5 [==============================] - 0s 16ms/step - loss: 0.1297 - accuracy: 0.9896 - val_loss: 1.0036 - val_accuracy: 0.6875
# Epoch 29/40
# 5/5 [==============================] - 0s 13ms/step - loss: 0.1306 - accuracy: 0.9882 - val_loss: 1.0348 - val_accuracy: 0.6875
# Epoch 30/40
# 5/5 [==============================] - 0s 14ms/step - loss: 0.1159 - accuracy: 0.9901 - val_loss: 1.0402 - val_accuracy: 0.7125

# %%
test_loss, test_acc  = model.evaluate(X_test, y_test, batch_size=128)
# Out:
# 2/2 [==============================] - 0s 3ms/step - loss: 1.4195 - accuracy: 0.6000

# %%
prediction = model.predict(X_test)
y_pred = []
for index, y_encode in enumerate(prediction):
    y_pred.append(np.argmax(y_encode))
corrMatrix = confusion_matrix(y_test, y_pred)
fig, ax = plt.subplots(figsize=(10,10))

sns.heatmap(corrMatrix, annot = True, xticklabels=genres, yticklabels=genres, cbar=False)
# Out:
# <AxesSubplot:>

# %%
fig, ax = plt.subplots(1,2,figsize=(30,15))

ax[0].plot(history.history['accuracy'])
ax[0].plot(history.history['val_accuracy'])
ax[1].plot(history.history['loss'])
ax[1].plot(history.history['val_loss'])
ax[0].legend(["Accuracy", "Validation Accuracy"])
ax[1].legend(["Loss", "Validation Loss"])
ax[0].set_ylabel("Accuracy")
ax[0].set_xlabel("Epoch")

ax[1].set_ylabel("Loss")
ax[1].set_xlabel("Epoch")
# Out:
# Text(0.5, 0, 'Epoch')

# %%
# initialize keras network
modeldropout = keras.Sequential()
modeldropout.add(keras.layers.Dense(256, activation='relu', input_shape=(X_train.shape[1],)))
modeldropout.add(keras.layers.Dropout(0.2))
modeldropout.add(keras.layers.Dense(128, activation='relu'))
modeldropout.add(keras.layers.Dropout(0.2))
modeldropout.add(keras.layers.Dense(64, activation='relu'))
modeldropout.add(keras.layers.Dropout(0.2))
modeldropout.add(keras.layers.Dense(10, activation='softmax'))

# %%
modeldropout.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
history = modeldropout.fit(X_train,
                    y_train,
                    epochs=40,
                    callbacks =[earlystopping],
                    validation_data=(X_val, y_val),
                    batch_size=128)
# Out:
# Epoch 1/40
# 5/5 [==============================] - 1s 54ms/step - loss: 2.3575 - accuracy: 0.1200 - val_loss: 2.1669 - val_accuracy: 0.2750
# Epoch 2/40
# 5/5 [==============================] - 0s 14ms/step - loss: 2.1188 - accuracy: 0.2347 - val_loss: 2.0031 - val_accuracy: 0.3688
# Epoch 3/40
# 5/5 [==============================] - 0s 16ms/step - loss: 1.9537 - accuracy: 0.3563 - val_loss: 1.8349 - val_accuracy: 0.4000
# Epoch 4/40
# 5/5 [==============================] - 0s 16ms/step - loss: 1.8108 - accuracy: 0.4196 - val_loss: 1.6820 - val_accuracy: 0.4125
# Epoch 5/40
# 5/5 [==============================] - 0s 15ms/step - loss: 1.6207 - accuracy: 0.4550 - val_loss: 1.5561 - val_accuracy: 0.4688
# Epoch 6/40
# 5/5 [==============================] - 0s 14ms/step - loss: 1.5166 - accuracy: 0.4838 - val_loss: 1.4606 - val_accuracy: 0.4812
# Epoch 7/40
# 5/5 [==============================] - 0s 13ms/step - loss: 1.3864 - accuracy: 0.5253 - val_loss: 1.3900 - val_accuracy: 0.4938
# Epoch 8/40
# 5/5 [==============================] - 0s 12ms/step - loss: 1.3233 - accuracy: 0.5391 - val_loss: 1.3169 - val_accuracy: 0.5375
# Epoch 9/40
# 5/5 [==============================] - 0s 17ms/step - loss: 1.2034 - accuracy: 0.5745 - val_loss: 1.2571 - val_accuracy: 0.5500
# Epoch 10/40
# 5/5 [==============================] - 0s 16ms/step - loss: 1.1923 - accuracy: 0.5581 - val_loss: 1.2443 - val_accuracy: 0.5375
# Epoch 11/40
# 5/5 [==============================] - 0s 13ms/step - loss: 1.1342 - accuracy: 0.6112 - val_loss: 1.2103 - val_accuracy: 0.5375
# Epoch 12/40
# 5/5 [==============================] - 0s 13ms/step - loss: 1.0963 - accuracy: 0.6172 - val_loss: 1.1593 - val_accuracy: 0.5500
# Epoch 13/40
# 5/5 [==============================] - 0s 15ms/step - loss: 1.0183 - accuracy: 0.6308 - val_loss: 1.1415 - val_accuracy: 0.5688
# Epoch 14/40
# 5/5 [==============================] - 0s 16ms/step - loss: 1.0110 - accuracy: 0.6313 - val_loss: 1.1387 - val_accuracy: 0.5813
# Epoch 15/40
# 5/5 [==============================] - 0s 13ms/step - loss: 0.9810 - accuracy: 0.6677 - val_loss: 1.1123 - val_accuracy: 0.5938
# Epoch 16/40
# 5/5 [==============================] - 0s 15ms/step - loss: 0.9540 - accuracy: 0.6617 - val_loss: 1.0658 - val_accuracy: 0.6062
# Epoch 17/40
# 5/5 [==============================] - 0s 18ms/step - loss: 0.9005 - accuracy: 0.7120 - val_loss: 1.0416 - val_accuracy: 0.6125
# Epoch 18/40
# 5/5 [==============================] - 0s 20ms/step - loss: 0.9139 - accuracy: 0.6827 - val_loss: 1.0376 - val_accuracy: 0.6250
# Epoch 19/40
# 5/5 [==============================] - 0s 15ms/step - loss: 0.7652 - accuracy: 0.7473 - val_loss: 1.0400 - val_accuracy: 0.6125
# Epoch 20/40
# 5/5 [==============================] - 0s 15ms/step - loss: 0.8503 - accuracy: 0.7294 - val_loss: 1.0355 - val_accuracy: 0.6125
# Epoch 21/40
# 5/5 [==============================] - 0s 15ms/step - loss: 0.7444 - accuracy: 0.7205 - val_loss: 0.9984 - val_accuracy: 0.6313
# Epoch 22/40
# 5/5 [==============================] - 0s 13ms/step - loss: 0.7609 - accuracy: 0.7285 - val_loss: 0.9694 - val_accuracy: 0.6375
# Epoch 23/40
# 5/5 [==============================] - 0s 13ms/step - loss: 0.7285 - accuracy: 0.7416 - val_loss: 0.9583 - val_accuracy: 0.6500
# Epoch 24/40
# 5/5 [==============================] - 0s 13ms/step - loss: 0.6777 - accuracy: 0.7837 - val_loss: 0.9712 - val_accuracy: 0.6375
# Epoch 25/40
# 5/5 [==============================] - 0s 14ms/step - loss: 0.7082 - accuracy: 0.7546 - val_loss: 0.9668 - val_accuracy: 0.6562
# Epoch 26/40
# 5/5 [==============================] - 0s 15ms/step - loss: 0.6023 - accuracy: 0.8061 - val_loss: 0.9602 - val_accuracy: 0.6625
# Epoch 27/40
# 5/5 [==============================] - 0s 13ms/step - loss: 0.6154 - accuracy: 0.7930 - val_loss: 0.9519 - val_accuracy: 0.6750
# Epoch 28/40
# 5/5 [==============================] - 0s 15ms/step - loss: 0.6899 - accuracy: 0.7479 - val_loss: 0.9341 - val_accuracy: 0.6625
# Epoch 29/40
# 5/5 [==============================] - 0s 16ms/step - loss: 0.6180 - accuracy: 0.7789 - val_loss: 0.9498 - val_accuracy: 0.6812
# Epoch 30/40
# 5/5 [==============================] - 0s 14ms/step - loss: 0.6201 - accuracy: 0.7932 - val_loss: 0.9520 - val_accuracy: 0.6750
# Epoch 31/40
# 5/5 [==============================] - 0s 14ms/step - loss: 0.5523 - accuracy: 0.8029 - val_loss: 0.9539 - val_accuracy: 0.6812
# Epoch 32/40
# 5/5 [==============================] - 0s 15ms/step - loss: 0.5530 - accuracy: 0.8246 - val_loss: 0.9389 - val_accuracy: 0.6687
# Epoch 33/40
# 5/5 [==============================] - 0s 19ms/step - loss: 0.5034 - accuracy: 0.8341 - val_loss: 0.9221 - val_accuracy: 0.6938
# Epoch 34/40
# 5/5 [==============================] - 0s 20ms/step - loss: 0.5374 - accuracy: 0.8260 - val_loss: 0.9111 - val_accuracy: 0.7063
# Epoch 35/40
# 5/5 [==============================] - 0s 14ms/step - loss: 0.5137 - accuracy: 0.8094 - val_loss: 0.9395 - val_accuracy: 0.6875
# Epoch 36/40
# 5/5 [==============================] - 0s 15ms/step - loss: 0.5142 - accuracy: 0.8362 - val_loss: 0.9362 - val_accuracy: 0.6938
# Epoch 37/40
# 5/5 [==============================] - 0s 16ms/step - loss: 0.4174 - accuracy: 0.8787 - val_loss: 0.9351 - val_accuracy: 0.7000
# Epoch 38/40
# 5/5 [==============================] - 0s 18ms/step - loss: 0.4254 - accuracy: 0.8590 - val_loss: 0.9476 - val_accuracy: 0.6938
# Epoch 39/40
# 5/5 [==============================] - 0s 17ms/step - loss: 0.4637 - accuracy: 0.8412 - val_loss: 0.9447 - val_accuracy: 0.6938
# Epoch 40/40
# 5/5 [==============================] - 0s 13ms/step - loss: 0.4164 - accuracy: 0.8679 - val_loss: 0.9365 - val_accuracy: 0.7188

# %%
test_loss, test_acc  = modeldropout.evaluate(X_test, y_test, batch_size=128)
# Out:
# 2/2 [==============================] - 0s 4ms/step - loss: 1.3350 - accuracy: 0.6150

# %%
prediction = modeldropout.predict(X_test)
y_pred = []
for index, y_encode in enumerate(prediction):
    y_pred.append(np.argmax(y_encode))
corrMatrix = confusion_matrix(y_test, y_pred)
fig, ax = plt.subplots(figsize=(10,10))

sns.heatmap(corrMatrix, annot = True, xticklabels=genres, yticklabels=genres, cbar=False)
# Out:
# <AxesSubplot:>

# %%
fig, ax = plt.subplots(1,2,figsize=(30,15))

ax[0].plot(history.history['accuracy'])
ax[0].plot(history.history['val_accuracy'])
ax[1].plot(history.history['loss'])
ax[1].plot(history.history['val_loss'])
ax[0].legend(["Accuracy", "Validation Accuracy"])
ax[1].legend(["Loss", "Validation Loss"])
ax[0].set_ylabel("Accuracy")
ax[0].set_xlabel("Epoch")

ax[1].set_ylabel("Loss")
ax[1].set_xlabel("Epoch")
# Out:
# Text(0.5, 0, 'Epoch')

# %%
modelReg = keras.Sequential()
modelReg.add(keras.layers.Dense(256, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(1e-4), input_shape=(X_train.shape[1],)))
modelReg.add(keras.layers.Dropout(0.2))
modelReg.add(keras.layers.Dense(128, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(1e-4)))
modelReg.add(keras.layers.Dropout(0.2))
modelReg.add(keras.layers.Dense(64, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(1e-4)))
modelReg.add(keras.layers.Dropout(0.2))
modelReg.add(keras.layers.Dense(10, activation='softmax', activity_regularizer=tf.keras.regularizers.l2(1e-4)))

modelReg.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
history = modelReg.fit(X_train,
                    y_train,
                    epochs=100,
                    callbacks =[earlystopping],
                    validation_data=(X_val, y_val),
                    batch_size=128)
# Out:
# Epoch 1/100
# 5/5 [==============================] - 1s 67ms/step - loss: 2.4060 - accuracy: 0.1245 - val_loss: 2.1378 - val_accuracy: 0.2937
# Epoch 2/100
# 5/5 [==============================] - 0s 13ms/step - loss: 2.1250 - accuracy: 0.2747 - val_loss: 1.9668 - val_accuracy: 0.3688
# Epoch 3/100
# 5/5 [==============================] - 0s 16ms/step - loss: 1.9330 - accuracy: 0.3483 - val_loss: 1.8077 - val_accuracy: 0.3688
# Epoch 4/100
# 5/5 [==============================] - 0s 14ms/step - loss: 1.7603 - accuracy: 0.4326 - val_loss: 1.6511 - val_accuracy: 0.3938
# Epoch 5/100
# 5/5 [==============================] - 0s 14ms/step - loss: 1.6223 - accuracy: 0.4331 - val_loss: 1.5234 - val_accuracy: 0.4375
# Epoch 6/100
# 5/5 [==============================] - 0s 15ms/step - loss: 1.5227 - accuracy: 0.4911 - val_loss: 1.4371 - val_accuracy: 0.4812
# Epoch 7/100
# 5/5 [==============================] - 0s 16ms/step - loss: 1.3622 - accuracy: 0.5404 - val_loss: 1.3650 - val_accuracy: 0.5250
# Epoch 8/100
# 5/5 [==============================] - 0s 15ms/step - loss: 1.2964 - accuracy: 0.5593 - val_loss: 1.2941 - val_accuracy: 0.5312
# Epoch 9/100
# 5/5 [==============================] - 0s 15ms/step - loss: 1.3387 - accuracy: 0.5400 - val_loss: 1.2570 - val_accuracy: 0.5312
# Epoch 10/100
# 5/5 [==============================] - 0s 14ms/step - loss: 1.1355 - accuracy: 0.6272 - val_loss: 1.2297 - val_accuracy: 0.5688
# Epoch 11/100
# 5/5 [==============================] - 0s 18ms/step - loss: 1.0545 - accuracy: 0.6351 - val_loss: 1.1849 - val_accuracy: 0.5813
# Epoch 12/100
# 5/5 [==============================] - 0s 14ms/step - loss: 1.1186 - accuracy: 0.5957 - val_loss: 1.1347 - val_accuracy: 0.6062
# Epoch 13/100
# 5/5 [==============================] - 0s 17ms/step - loss: 0.9952 - accuracy: 0.6615 - val_loss: 1.1157 - val_accuracy: 0.6125
# Epoch 14/100
# 5/5 [==============================] - 0s 14ms/step - loss: 1.0219 - accuracy: 0.6432 - val_loss: 1.0906 - val_accuracy: 0.6187
# Epoch 15/100
# 5/5 [==============================] - 0s 12ms/step - loss: 0.9459 - accuracy: 0.6929 - val_loss: 1.0890 - val_accuracy: 0.6250
# Epoch 16/100
# 5/5 [==============================] - 0s 16ms/step - loss: 0.9330 - accuracy: 0.6840 - val_loss: 1.0676 - val_accuracy: 0.6313
# Epoch 17/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.8806 - accuracy: 0.7218 - val_loss: 1.0323 - val_accuracy: 0.6375
# Epoch 18/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.8415 - accuracy: 0.7160 - val_loss: 0.9972 - val_accuracy: 0.6687
# Epoch 19/100
# 5/5 [==============================] - 0s 16ms/step - loss: 0.8749 - accuracy: 0.7195 - val_loss: 0.9992 - val_accuracy: 0.6687
# Epoch 20/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.8276 - accuracy: 0.7345 - val_loss: 1.0017 - val_accuracy: 0.6750
# Epoch 21/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.7804 - accuracy: 0.7651 - val_loss: 1.0001 - val_accuracy: 0.6687
# Epoch 22/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.7195 - accuracy: 0.7667 - val_loss: 0.9943 - val_accuracy: 0.6812
# Epoch 23/100
# 5/5 [==============================] - 0s 17ms/step - loss: 0.7481 - accuracy: 0.7694 - val_loss: 0.9820 - val_accuracy: 0.7063
# Epoch 24/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.6714 - accuracy: 0.7767 - val_loss: 0.9808 - val_accuracy: 0.7188
# Epoch 25/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.6405 - accuracy: 0.7950 - val_loss: 0.9600 - val_accuracy: 0.7125
# Epoch 26/100
# 5/5 [==============================] - 0s 16ms/step - loss: 0.6463 - accuracy: 0.8185 - val_loss: 0.9697 - val_accuracy: 0.7000
# Epoch 27/100
# 5/5 [==============================] - 0s 17ms/step - loss: 0.6079 - accuracy: 0.8176 - val_loss: 0.9913 - val_accuracy: 0.7125
# Epoch 28/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.5979 - accuracy: 0.7979 - val_loss: 0.9818 - val_accuracy: 0.7063
# Epoch 29/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.5915 - accuracy: 0.8221 - val_loss: 0.9845 - val_accuracy: 0.6687
# Epoch 30/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.5776 - accuracy: 0.8173 - val_loss: 0.9621 - val_accuracy: 0.6875
# Epoch 31/100
# 5/5 [==============================] - 0s 16ms/step - loss: 0.5409 - accuracy: 0.8341 - val_loss: 0.9576 - val_accuracy: 0.7125
# Epoch 32/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.5605 - accuracy: 0.8264 - val_loss: 0.9522 - val_accuracy: 0.7000
# Epoch 33/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.5580 - accuracy: 0.8159 - val_loss: 0.9552 - val_accuracy: 0.7000
# Epoch 34/100
# 5/5 [==============================] - 0s 12ms/step - loss: 0.4777 - accuracy: 0.8692 - val_loss: 0.9624 - val_accuracy: 0.7312
# Epoch 35/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.4866 - accuracy: 0.8347 - val_loss: 0.9486 - val_accuracy: 0.7312
# Epoch 36/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.4670 - accuracy: 0.8770 - val_loss: 0.9450 - val_accuracy: 0.7437
# Epoch 37/100
# 5/5 [==============================] - 0s 16ms/step - loss: 0.4880 - accuracy: 0.8383 - val_loss: 0.9604 - val_accuracy: 0.7063
# Epoch 38/100
# 5/5 [==============================] - 0s 16ms/step - loss: 0.4512 - accuracy: 0.8759 - val_loss: 0.9773 - val_accuracy: 0.7250
# Epoch 39/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.4772 - accuracy: 0.8492 - val_loss: 0.9505 - val_accuracy: 0.7500
# Epoch 40/100
# 5/5 [==============================] - 0s 16ms/step - loss: 0.4390 - accuracy: 0.8804 - val_loss: 0.9485 - val_accuracy: 0.7125
# Epoch 41/100
# 5/5 [==============================] - 0s 18ms/step - loss: 0.4132 - accuracy: 0.8706 - val_loss: 0.9548 - val_accuracy: 0.7188
# Epoch 42/100
# 5/5 [==============================] - 0s 17ms/step - loss: 0.3649 - accuracy: 0.8954 - val_loss: 0.9613 - val_accuracy: 0.7000
# Epoch 43/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.4051 - accuracy: 0.8779 - val_loss: 0.9774 - val_accuracy: 0.7125
# Epoch 44/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.4063 - accuracy: 0.8908 - val_loss: 0.9830 - val_accuracy: 0.7125
# Epoch 45/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.3904 - accuracy: 0.8941 - val_loss: 1.0242 - val_accuracy: 0.7000
# Epoch 46/100
# 5/5 [==============================] - 0s 12ms/step - loss: 0.3581 - accuracy: 0.8864 - val_loss: 1.0422 - val_accuracy: 0.7000

# %%
test_loss, test_acc  = modelReg.evaluate(X_test, y_test, batch_size=128)
# Out:
# 2/2 [==============================] - 0s 2ms/step - loss: 1.3291 - accuracy: 0.6050

# %%
prediction = modelReg.predict(X_test)
y_pred = []
for index, y_encode in enumerate(prediction):
    y_pred.append(np.argmax(y_encode))
corrMatrix = confusion_matrix(y_test, y_pred)
fig, ax = plt.subplots(figsize=(10,10))

sns.heatmap(corrMatrix, annot = True, xticklabels=genres, yticklabels=genres, cbar=False)
# Out:
# <AxesSubplot:>

# %%
fig, ax = plt.subplots(1,2,figsize=(30,15))

ax[0].plot(history.history['accuracy'])
ax[0].plot(history.history['val_accuracy'])
ax[1].plot(history.history['loss'])
ax[1].plot(history.history['val_loss'])
ax[0].legend(["Accuracy", "Validation Accuracy"])
ax[1].legend(["Loss", "Validation Loss"])
ax[0].set_ylabel("Accuracy")
ax[0].set_xlabel("Epoch")

ax[1].set_ylabel("Loss")
ax[1].set_xlabel("Epoch")
# Out:
# Text(0.5, 0, 'Epoch')
