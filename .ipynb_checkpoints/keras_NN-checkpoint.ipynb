# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler

#Keras
import keras

# import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import seaborn as sns
import tensorflow as tf
from sklearn.utils import shuffle
from sklearn.metrics import confusion_matrix

plt.style.use('ggplot')
import librosa
from librosa import feature
from librosa import display
genres = [
    'blues', 'classical', 'country', 'disco', 'hiphop', 'jazz', 'metal', 'pop',
    'reggae', 'rock'
]

# %%
# load dataframe from csv
dfFeatures = pd.read_csv("music_features.csv")



# extract genres for labels
genreList = dfFeatures['genre']

# drop genres and filenames for training data
dfFeatures= dfFeatures.drop(columns = ['filename', 'genre'])

dfFeatures.head()
# Out:
#    chroma_stft_mean  spectral_centroid_mean  spectral_bandwidth_mean  \
# 0          0.342053             1782.622682              2020.556328
# 1          0.358000             1364.273766              1842.030467
# 2          0.382027             1521.556846              1736.799388
# 3          0.391765              947.018874              1427.836298
# 4          0.316456             2046.427867              1858.463045
#
#    rolloff_mean  zero_crossing_rate_mean       tempo  mfcc1_mean  mfcc2_mean  \
# 0   3845.075667                 0.080111  123.046875 -125.188171  120.222137
# 1   2976.303348                 0.055211  107.666016 -221.931198  131.147629
# 2   3028.062974                 0.070182  151.999081  -99.112022  141.554123
# 3   1863.946038                 0.030092   63.024009 -214.465668  156.586929
# 4   4005.025898                 0.116385  135.999178 -151.967178  115.340431
#
#    mfcc3_mean  mfcc4_mean  ...  mfcc11_mean  mfcc12_mean  mfcc13_mean  \
# 0  -18.358818   44.887314  ...    -8.861547     9.301556    -4.159669
# 1    0.490468   39.101952  ...    -3.123051     6.931743    -1.881995
# 2  -25.738703   34.465645  ...   -12.999936     4.544575    -8.695225
# 3    2.785257   26.750803  ...     2.481811     4.701363    -2.364664
# 4  -31.880495   23.762522  ...   -16.674786    -4.082293    -4.755991
#
#    mfcc14_mean  mfcc15_mean  mfcc16_mean  mfcc17_mean  mfcc18_mean  \
# 0     7.119120    -5.663028     0.530103    -2.870996     0.306077
# 1     4.951429    -4.531081    -0.463962     0.497853     0.039326
# 2    -2.315017    -8.144971     2.917833    -6.660074    -2.039234
# 3    -0.866406    -3.422017    -0.273013     0.231585     2.437521
# 4    -7.974098    -9.649985    -2.115260    -8.198335    -1.059961
#
#    mfcc19_mean  mfcc20_mean
# 0    -2.700369     2.370232
# 1    -1.083576    -0.112309
# 2    -2.045270    -2.697336
# 3     1.284240    -2.200283
# 4    -3.900608   -12.995133
#
# [5 rows x 26 columns]

# %%
# standardize data  
scaler = StandardScaler()
X = scaler.fit_transform(np.array(dfFeatures.iloc[:, :-1], dtype = float))

# encode labels 
encoder = LabelEncoder()
y = encoder.fit_transform(genreList)

# split into training and test data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state = 2)
X_train, X_val, y_train, y_val  = train_test_split(X_train, y_train, test_size=0.25, random_state=2)

# %%
# initialize keras network
model = keras.Sequential()
model.add(keras.layers.Dense(256, activation='relu', input_shape=(X_train.shape[1],)))
model.add(keras.layers.Dense(128, activation='relu'))
model.add(keras.layers.Dense(64, activation='relu'))
model.add(keras.layers.Dense(10, activation='softmax'))

# %%
# configure model for training
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
# train model

# https://www.geeksforgeeks.org/choose-optimal-number-of-epochs-to-train-a-neural-network-in-keras/
from keras import callbacks

#callback to prevent overfitting
earlystopping = callbacks.EarlyStopping(monitor ="val_loss", 
                                        mode ="min", patience = 5, 
                                        restore_best_weights = True)


history = model.fit(X_train,
                    y_train,
                    validation_data=(X_val, y_val),
                    epochs=100,
                    batch_size=128,
                    callbacks =[earlystopping])
# Out:
# Epoch 1/100
# 5/5 [==============================] - 2s 270ms/step - loss: 2.2522 - accuracy: 0.1238 - val_loss: 2.0406 - val_accuracy: 0.3550
# Epoch 2/100
# 5/5 [==============================] - 0s 13ms/step - loss: 1.9879 - accuracy: 0.3685 - val_loss: 1.8685 - val_accuracy: 0.3650
# Epoch 3/100
# 5/5 [==============================] - 0s 13ms/step - loss: 1.7726 - accuracy: 0.4421 - val_loss: 1.7291 - val_accuracy: 0.3750
# Epoch 4/100
# 5/5 [==============================] - 0s 16ms/step - loss: 1.5883 - accuracy: 0.4389 - val_loss: 1.6129 - val_accuracy: 0.4300
# Epoch 5/100
# 5/5 [==============================] - 0s 21ms/step - loss: 1.4793 - accuracy: 0.4962 - val_loss: 1.5263 - val_accuracy: 0.4350
# Epoch 6/100
# 5/5 [==============================] - 0s 13ms/step - loss: 1.3552 - accuracy: 0.5465 - val_loss: 1.4396 - val_accuracy: 0.4750
# Epoch 7/100
# 5/5 [==============================] - 0s 14ms/step - loss: 1.2696 - accuracy: 0.5803 - val_loss: 1.3779 - val_accuracy: 0.5450
# Epoch 8/100
# 5/5 [==============================] - 0s 14ms/step - loss: 1.1917 - accuracy: 0.5973 - val_loss: 1.3512 - val_accuracy: 0.5150
# Epoch 9/100
# 5/5 [==============================] - 0s 15ms/step - loss: 1.1447 - accuracy: 0.6222 - val_loss: 1.3251 - val_accuracy: 0.5400
# Epoch 10/100
# 5/5 [==============================] - 0s 15ms/step - loss: 1.0627 - accuracy: 0.6452 - val_loss: 1.2741 - val_accuracy: 0.6000
# Epoch 11/100
# 5/5 [==============================] - 0s 15ms/step - loss: 1.0406 - accuracy: 0.6746 - val_loss: 1.2638 - val_accuracy: 0.5800
# Epoch 12/100
# 5/5 [==============================] - 0s 12ms/step - loss: 0.9575 - accuracy: 0.6987 - val_loss: 1.2458 - val_accuracy: 0.5900
# Epoch 13/100
# 5/5 [==============================] - 0s 11ms/step - loss: 0.9205 - accuracy: 0.6837 - val_loss: 1.2342 - val_accuracy: 0.6000
# Epoch 14/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.9377 - accuracy: 0.6871 - val_loss: 1.2315 - val_accuracy: 0.5950
# Epoch 15/100
# 5/5 [==============================] - 0s 16ms/step - loss: 0.8451 - accuracy: 0.7552 - val_loss: 1.2003 - val_accuracy: 0.6150
# Epoch 16/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.7798 - accuracy: 0.7630 - val_loss: 1.2052 - val_accuracy: 0.6050
# Epoch 17/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.7338 - accuracy: 0.7809 - val_loss: 1.1954 - val_accuracy: 0.6150
# Epoch 18/100
# 5/5 [==============================] - 0s 11ms/step - loss: 0.7143 - accuracy: 0.7844 - val_loss: 1.1734 - val_accuracy: 0.6200
# Epoch 19/100
# 5/5 [==============================] - 0s 11ms/step - loss: 0.7084 - accuracy: 0.7792 - val_loss: 1.1950 - val_accuracy: 0.6150
# Epoch 20/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.6740 - accuracy: 0.7992 - val_loss: 1.1881 - val_accuracy: 0.6250
# Epoch 21/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.6203 - accuracy: 0.8180 - val_loss: 1.1887 - val_accuracy: 0.6300
# Epoch 22/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.5627 - accuracy: 0.8392 - val_loss: 1.1896 - val_accuracy: 0.6300
# Epoch 23/100
# 5/5 [==============================] - 0s 11ms/step - loss: 0.5560 - accuracy: 0.8457 - val_loss: 1.1889 - val_accuracy: 0.6450
# Epoch 24/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.5428 - accuracy: 0.8498 - val_loss: 1.2038 - val_accuracy: 0.6450
# Epoch 25/100
# 5/5 [==============================] - 0s 12ms/step - loss: 0.5382 - accuracy: 0.8481 - val_loss: 1.2034 - val_accuracy: 0.6350
# Epoch 26/100
# 5/5 [==============================] - 0s 12ms/step - loss: 0.5072 - accuracy: 0.8678 - val_loss: 1.2063 - val_accuracy: 0.6300
# Epoch 27/100
# 5/5 [==============================] - 0s 11ms/step - loss: 0.4776 - accuracy: 0.8871 - val_loss: 1.2186 - val_accuracy: 0.6450
# Epoch 28/100
# 5/5 [==============================] - 0s 12ms/step - loss: 0.4295 - accuracy: 0.8948 - val_loss: 1.2426 - val_accuracy: 0.6500

# %%
test_loss, test_acc  = model.evaluate(X_test, y_test, batch_size=128)
# Out:
# 2/2 [==============================] - 0s 2ms/step - loss: 1.1502 - accuracy: 0.6050

# %%
prediction = model.predict(X_test)
y_pred = []
for index, y_encode in enumerate(prediction):
    y_pred.append(np.argmax(y_encode))
corrMatrix = confusion_matrix(y_test, y_pred)
fig, ax = plt.subplots(figsize=(10,10))

sns.heatmap(corrMatrix, annot = True, xticklabels=genres, yticklabels=genres, cbar=False).set_title("Dataset 1: Confusion Matrix: Base Model")
# Out:
# Text(0.5, 1.0, 'Dataset 1: Confusion Matrix: Base Model')

# %%
fig, ax = plt.subplots(1,2,figsize=(30,15))

ax[0].plot(history.history['accuracy'])
ax[0].plot(history.history['val_accuracy'])
ax[1].plot(history.history['loss'])
ax[1].plot(history.history['val_loss'])
ax[0].legend(["Accuracy", "Validation Accuracy"])
ax[1].legend(["Loss", "Validation Loss"])
ax[0].set_ylabel("Accuracy")
ax[0].set_xlabel("Epoch")
ax[0].set_title("Dataset 1: Base Model: Accuracy")
ax[1].set_title("Dataset 1: Base Model: Loss")
ax[1].set_ylabel("Loss")
ax[1].set_xlabel("Epoch")
# Out:
# Text(0.5, 0, 'Epoch')

# %%
# initialize keras network
modeldropout = keras.Sequential()
modeldropout.add(keras.layers.Dense(256, activation='relu', input_shape=(X_train.shape[1],)))
modeldropout.add(keras.layers.Dropout(0.2))
modeldropout.add(keras.layers.Dense(128, activation='relu'))
modeldropout.add(keras.layers.Dropout(0.2))
modeldropout.add(keras.layers.Dense(64, activation='relu'))
modeldropout.add(keras.layers.Dropout(0.2))
modeldropout.add(keras.layers.Dense(10, activation='softmax'))

# %%
modeldropout.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
history = modeldropout.fit(X_train,
                    y_train,
                    epochs=100,
                    callbacks =[earlystopping],
                    validation_data=(X_val, y_val),
                    batch_size=128)
# Out:
# Epoch 1/100
# 5/5 [==============================] - 1s 72ms/step - loss: 2.3103 - accuracy: 0.1418 - val_loss: 2.1316 - val_accuracy: 0.3000
# Epoch 2/100
# 5/5 [==============================] - 0s 19ms/step - loss: 2.1102 - accuracy: 0.2790 - val_loss: 1.9982 - val_accuracy: 0.3800
# Epoch 3/100
# 5/5 [==============================] - 0s 18ms/step - loss: 1.9976 - accuracy: 0.3410 - val_loss: 1.8929 - val_accuracy: 0.3800
# Epoch 4/100
# 5/5 [==============================] - 0s 20ms/step - loss: 1.8890 - accuracy: 0.3703 - val_loss: 1.7970 - val_accuracy: 0.3850
# Epoch 5/100
# 5/5 [==============================] - 0s 19ms/step - loss: 1.8133 - accuracy: 0.3688 - val_loss: 1.7119 - val_accuracy: 0.3950
# Epoch 6/100
# 5/5 [==============================] - 0s 23ms/step - loss: 1.7092 - accuracy: 0.4115 - val_loss: 1.6330 - val_accuracy: 0.4200
# Epoch 7/100
# 5/5 [==============================] - 0s 20ms/step - loss: 1.6045 - accuracy: 0.4449 - val_loss: 1.5583 - val_accuracy: 0.4450
# Epoch 8/100
# 5/5 [==============================] - 0s 23ms/step - loss: 1.6079 - accuracy: 0.4075 - val_loss: 1.5021 - val_accuracy: 0.4350
# Epoch 9/100
# 5/5 [==============================] - 0s 19ms/step - loss: 1.4924 - accuracy: 0.4910 - val_loss: 1.4603 - val_accuracy: 0.4650
# Epoch 10/100
# 5/5 [==============================] - 0s 17ms/step - loss: 1.4360 - accuracy: 0.4878 - val_loss: 1.4183 - val_accuracy: 0.4750
# Epoch 11/100
# 5/5 [==============================] - 0s 17ms/step - loss: 1.4399 - accuracy: 0.5015 - val_loss: 1.3836 - val_accuracy: 0.4900
# Epoch 12/100
# 5/5 [==============================] - 0s 15ms/step - loss: 1.3500 - accuracy: 0.5317 - val_loss: 1.3428 - val_accuracy: 0.5050
# Epoch 13/100
# 5/5 [==============================] - 0s 16ms/step - loss: 1.3551 - accuracy: 0.5213 - val_loss: 1.3184 - val_accuracy: 0.5150
# Epoch 14/100
# 5/5 [==============================] - 0s 15ms/step - loss: 1.2860 - accuracy: 0.5316 - val_loss: 1.2876 - val_accuracy: 0.5400
# Epoch 15/100
# 5/5 [==============================] - 0s 13ms/step - loss: 1.2384 - accuracy: 0.5680 - val_loss: 1.2629 - val_accuracy: 0.5600
# Epoch 16/100
# 5/5 [==============================] - 0s 15ms/step - loss: 1.2315 - accuracy: 0.5606 - val_loss: 1.2531 - val_accuracy: 0.5600
# Epoch 17/100
# 5/5 [==============================] - 0s 14ms/step - loss: 1.2005 - accuracy: 0.5880 - val_loss: 1.2301 - val_accuracy: 0.5650
# Epoch 18/100
# 5/5 [==============================] - 0s 16ms/step - loss: 1.1137 - accuracy: 0.6154 - val_loss: 1.2136 - val_accuracy: 0.5750
# Epoch 19/100
# 5/5 [==============================] - 0s 16ms/step - loss: 1.1249 - accuracy: 0.6054 - val_loss: 1.1912 - val_accuracy: 0.6000
# Epoch 20/100
# 5/5 [==============================] - 0s 14ms/step - loss: 1.0989 - accuracy: 0.6123 - val_loss: 1.1971 - val_accuracy: 0.5900
# Epoch 21/100
# 5/5 [==============================] - 0s 20ms/step - loss: 1.1038 - accuracy: 0.6040 - val_loss: 1.2033 - val_accuracy: 0.5850
# Epoch 22/100
# 5/5 [==============================] - 0s 23ms/step - loss: 1.0210 - accuracy: 0.6369 - val_loss: 1.1823 - val_accuracy: 0.6100
# Epoch 23/100
# 5/5 [==============================] - 0s 18ms/step - loss: 1.0057 - accuracy: 0.6338 - val_loss: 1.1730 - val_accuracy: 0.6150
# Epoch 24/100
# 5/5 [==============================] - 0s 16ms/step - loss: 1.0223 - accuracy: 0.6567 - val_loss: 1.1730 - val_accuracy: 0.6150
# Epoch 25/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.9795 - accuracy: 0.6771 - val_loss: 1.1661 - val_accuracy: 0.6200
# Epoch 26/100
# 5/5 [==============================] - 0s 16ms/step - loss: 0.9837 - accuracy: 0.6588 - val_loss: 1.1732 - val_accuracy: 0.6100
# Epoch 27/100
# 5/5 [==============================] - 0s 19ms/step - loss: 0.8918 - accuracy: 0.7132 - val_loss: 1.1655 - val_accuracy: 0.6200
# Epoch 28/100
# 5/5 [==============================] - 0s 19ms/step - loss: 0.9213 - accuracy: 0.7009 - val_loss: 1.1592 - val_accuracy: 0.6150
# Epoch 29/100
# 5/5 [==============================] - 0s 16ms/step - loss: 0.9257 - accuracy: 0.6841 - val_loss: 1.1604 - val_accuracy: 0.6100
# Epoch 30/100
# 5/5 [==============================] - 0s 18ms/step - loss: 0.8873 - accuracy: 0.6887 - val_loss: 1.1373 - val_accuracy: 0.6050
# Epoch 31/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.8653 - accuracy: 0.7018 - val_loss: 1.1466 - val_accuracy: 0.6200
# Epoch 32/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.8169 - accuracy: 0.7220 - val_loss: 1.1580 - val_accuracy: 0.6250
# Epoch 33/100
# 5/5 [==============================] - 0s 21ms/step - loss: 0.7998 - accuracy: 0.7265 - val_loss: 1.1374 - val_accuracy: 0.6300
# Epoch 34/100
# 5/5 [==============================] - 0s 23ms/step - loss: 0.8198 - accuracy: 0.7496 - val_loss: 1.1248 - val_accuracy: 0.6550
# Epoch 35/100
# 5/5 [==============================] - 0s 16ms/step - loss: 0.7818 - accuracy: 0.7187 - val_loss: 1.1411 - val_accuracy: 0.6200
# Epoch 36/100
# 5/5 [==============================] - 0s 17ms/step - loss: 0.8037 - accuracy: 0.7308 - val_loss: 1.1446 - val_accuracy: 0.6250
# Epoch 37/100
# 5/5 [==============================] - 0s 19ms/step - loss: 0.7297 - accuracy: 0.7558 - val_loss: 1.1371 - val_accuracy: 0.6300
# Epoch 38/100
# 5/5 [==============================] - 0s 17ms/step - loss: 0.7480 - accuracy: 0.7488 - val_loss: 1.1392 - val_accuracy: 0.6300
# Epoch 39/100
# 5/5 [==============================] - 0s 18ms/step - loss: 0.7376 - accuracy: 0.7443 - val_loss: 1.1662 - val_accuracy: 0.6350
# Epoch 40/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.6993 - accuracy: 0.7800 - val_loss: 1.1536 - val_accuracy: 0.6350
# Epoch 41/100
# 5/5 [==============================] - 0s 17ms/step - loss: 0.7247 - accuracy: 0.7338 - val_loss: 1.1421 - val_accuracy: 0.6400
# Epoch 42/100
# 5/5 [==============================] - 0s 16ms/step - loss: 0.6701 - accuracy: 0.7760 - val_loss: 1.1422 - val_accuracy: 0.6500
# Epoch 43/100
# 5/5 [==============================] - 0s 17ms/step - loss: 0.6923 - accuracy: 0.7486 - val_loss: 1.1830 - val_accuracy: 0.6300
# Epoch 44/100
# 5/5 [==============================] - 0s 17ms/step - loss: 0.6823 - accuracy: 0.7586 - val_loss: 1.1630 - val_accuracy: 0.6450

# %%
test_loss, test_acc  = modeldropout.evaluate(X_test, y_test, batch_size=128)
# Out:
# 2/2 [==============================] - 0s 5ms/step - loss: 1.1349 - accuracy: 0.5950

# %%
prediction = modeldropout.predict(X_test)
y_pred = []
for index, y_encode in enumerate(prediction):
    y_pred.append(np.argmax(y_encode))
corrMatrix = confusion_matrix(y_test, y_pred)
fig, ax = plt.subplots(figsize=(10,10))

sns.heatmap(corrMatrix, annot = True, xticklabels=genres, yticklabels=genres, cbar=False).set_title("Dataset 1: Confusion Matrix: Model w/ Dropout")
# Out:
# Text(0.5, 1.0, 'Dataset 1: Confusion Matrix: Model w/ Dropout')

# %%
fig, ax = plt.subplots(1,2,figsize=(30,15))

ax[0].plot(history.history['accuracy'])
ax[0].plot(history.history['val_accuracy'])
ax[1].plot(history.history['loss'])
ax[1].plot(history.history['val_loss'])
ax[0].legend(["Accuracy", "Validation Accuracy"])
ax[1].legend(["Loss", "Validation Loss"])
ax[0].set_ylabel("Accuracy")
ax[0].set_xlabel("Epoch")
ax[0].set_title("Dataset 1: Model with Dropout: Accuracy")
ax[1].set_title("Dataset 1: Model with Dropout: Loss")
ax[1].set_ylabel("Loss")
ax[1].set_xlabel("Epoch")
# Out:
# Text(0.5, 0, 'Epoch')

# %%
modelReg = keras.Sequential()
modelReg.add(keras.layers.Dense(256, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(1e-4), input_shape=(X_train.shape[1],)))
modelReg.add(keras.layers.Dropout(0.2))
modelReg.add(keras.layers.Dense(128, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(1e-4)))
modelReg.add(keras.layers.Dropout(0.2))
modelReg.add(keras.layers.Dense(64, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(1e-4)))
modelReg.add(keras.layers.Dropout(0.2))
modelReg.add(keras.layers.Dense(10, activation='softmax', activity_regularizer=tf.keras.regularizers.l2(1e-4)))

# %%
modelReg.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
history = modelReg.fit(X_train,
                    y_train,
                    epochs=100,
                    callbacks =[earlystopping],
                    validation_data=(X_val, y_val),
                    batch_size=128)
# Out:
# Epoch 1/100
# 5/5 [==============================] - 1s 84ms/step - loss: 2.3720 - accuracy: 0.0932 - val_loss: 2.1825 - val_accuracy: 0.2750
# Epoch 2/100
# 5/5 [==============================] - 0s 18ms/step - loss: 2.1772 - accuracy: 0.2433 - val_loss: 2.0500 - val_accuracy: 0.3150
# Epoch 3/100
# 5/5 [==============================] - 0s 16ms/step - loss: 2.0441 - accuracy: 0.3284 - val_loss: 1.9174 - val_accuracy: 0.3300
# Epoch 4/100
# 5/5 [==============================] - 0s 17ms/step - loss: 1.9064 - accuracy: 0.3401 - val_loss: 1.8024 - val_accuracy: 0.3500
# Epoch 5/100
# 5/5 [==============================] - 0s 14ms/step - loss: 1.7904 - accuracy: 0.3810 - val_loss: 1.7072 - val_accuracy: 0.3650
# Epoch 6/100
# 5/5 [==============================] - 0s 14ms/step - loss: 1.6844 - accuracy: 0.4170 - val_loss: 1.6279 - val_accuracy: 0.3850
# Epoch 7/100
# 5/5 [==============================] - 0s 18ms/step - loss: 1.6588 - accuracy: 0.4249 - val_loss: 1.5511 - val_accuracy: 0.4050
# Epoch 8/100
# 5/5 [==============================] - 0s 16ms/step - loss: 1.5646 - accuracy: 0.4489 - val_loss: 1.4922 - val_accuracy: 0.4150
# Epoch 9/100
# 5/5 [==============================] - 0s 17ms/step - loss: 1.4672 - accuracy: 0.4825 - val_loss: 1.4483 - val_accuracy: 0.4350
# Epoch 10/100
# 5/5 [==============================] - 0s 14ms/step - loss: 1.4526 - accuracy: 0.5009 - val_loss: 1.4073 - val_accuracy: 0.4700
# Epoch 11/100
# 5/5 [==============================] - 0s 17ms/step - loss: 1.4257 - accuracy: 0.4911 - val_loss: 1.3808 - val_accuracy: 0.5000
# Epoch 12/100
# 5/5 [==============================] - 0s 15ms/step - loss: 1.3518 - accuracy: 0.5062 - val_loss: 1.3506 - val_accuracy: 0.5300
# Epoch 13/100
# 5/5 [==============================] - 0s 15ms/step - loss: 1.3370 - accuracy: 0.5353 - val_loss: 1.3309 - val_accuracy: 0.5200
# Epoch 14/100
# 5/5 [==============================] - 0s 15ms/step - loss: 1.2838 - accuracy: 0.5599 - val_loss: 1.3103 - val_accuracy: 0.5350
# Epoch 15/100
# 5/5 [==============================] - 0s 16ms/step - loss: 1.2890 - accuracy: 0.5697 - val_loss: 1.2828 - val_accuracy: 0.5750
# Epoch 16/100
# 5/5 [==============================] - 0s 18ms/step - loss: 1.1986 - accuracy: 0.6097 - val_loss: 1.2644 - val_accuracy: 0.6000
# Epoch 17/100
# 5/5 [==============================] - 0s 16ms/step - loss: 1.1919 - accuracy: 0.5851 - val_loss: 1.2490 - val_accuracy: 0.5800
# Epoch 18/100
# 5/5 [==============================] - 0s 16ms/step - loss: 1.1157 - accuracy: 0.6039 - val_loss: 1.2455 - val_accuracy: 0.6000
# Epoch 19/100
# 5/5 [==============================] - 0s 17ms/step - loss: 1.1464 - accuracy: 0.6100 - val_loss: 1.2335 - val_accuracy: 0.6000
# Epoch 20/100
# 5/5 [==============================] - 0s 14ms/step - loss: 1.0968 - accuracy: 0.6520 - val_loss: 1.2291 - val_accuracy: 0.6050
# Epoch 21/100
# 5/5 [==============================] - 0s 18ms/step - loss: 1.0903 - accuracy: 0.6405 - val_loss: 1.2273 - val_accuracy: 0.5950
# Epoch 22/100
# 5/5 [==============================] - 0s 16ms/step - loss: 1.0561 - accuracy: 0.6776 - val_loss: 1.2282 - val_accuracy: 0.6000
# Epoch 23/100
# 5/5 [==============================] - 0s 14ms/step - loss: 1.0280 - accuracy: 0.6558 - val_loss: 1.2075 - val_accuracy: 0.6100
# Epoch 24/100
# 5/5 [==============================] - 0s 15ms/step - loss: 1.0514 - accuracy: 0.6809 - val_loss: 1.1884 - val_accuracy: 0.6300
# Epoch 25/100
# 5/5 [==============================] - 0s 16ms/step - loss: 1.0429 - accuracy: 0.6509 - val_loss: 1.1836 - val_accuracy: 0.6300
# Epoch 26/100
# 5/5 [==============================] - 0s 16ms/step - loss: 0.9893 - accuracy: 0.6817 - val_loss: 1.1964 - val_accuracy: 0.6150
# Epoch 27/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.9679 - accuracy: 0.6942 - val_loss: 1.1864 - val_accuracy: 0.6000
# Epoch 28/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.9078 - accuracy: 0.6952 - val_loss: 1.1776 - val_accuracy: 0.6250
# Epoch 29/100
# 5/5 [==============================] - 0s 16ms/step - loss: 0.9679 - accuracy: 0.6759 - val_loss: 1.1743 - val_accuracy: 0.6250
# Epoch 30/100
# 5/5 [==============================] - 0s 16ms/step - loss: 0.9200 - accuracy: 0.7079 - val_loss: 1.1800 - val_accuracy: 0.6250
# Epoch 31/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.9189 - accuracy: 0.7012 - val_loss: 1.1789 - val_accuracy: 0.6300
# Epoch 32/100
# 5/5 [==============================] - 0s 17ms/step - loss: 0.8813 - accuracy: 0.6920 - val_loss: 1.1679 - val_accuracy: 0.6500
# Epoch 33/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.8865 - accuracy: 0.6946 - val_loss: 1.1805 - val_accuracy: 0.6350
# Epoch 34/100
# 5/5 [==============================] - 0s 17ms/step - loss: 0.8436 - accuracy: 0.7287 - val_loss: 1.1948 - val_accuracy: 0.6200
# Epoch 35/100
# 5/5 [==============================] - 0s 16ms/step - loss: 0.7902 - accuracy: 0.7453 - val_loss: 1.1725 - val_accuracy: 0.6500
# Epoch 36/100
# 5/5 [==============================] - 0s 16ms/step - loss: 0.8136 - accuracy: 0.7158 - val_loss: 1.1708 - val_accuracy: 0.6400
# Epoch 37/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.8181 - accuracy: 0.7322 - val_loss: 1.1789 - val_accuracy: 0.6400
# Epoch 38/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.7451 - accuracy: 0.7750 - val_loss: 1.1725 - val_accuracy: 0.6500
# Epoch 39/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.7934 - accuracy: 0.7469 - val_loss: 1.1803 - val_accuracy: 0.6350
# Epoch 40/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.7462 - accuracy: 0.7469 - val_loss: 1.1651 - val_accuracy: 0.6400
# Epoch 41/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.7688 - accuracy: 0.7489 - val_loss: 1.1615 - val_accuracy: 0.6600
# Epoch 42/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.7178 - accuracy: 0.7541 - val_loss: 1.1772 - val_accuracy: 0.6500
# Epoch 43/100
# 5/5 [==============================] - 0s 16ms/step - loss: 0.7247 - accuracy: 0.7548 - val_loss: 1.1913 - val_accuracy: 0.6500
# Epoch 44/100
# 5/5 [==============================] - 0s 17ms/step - loss: 0.7534 - accuracy: 0.7403 - val_loss: 1.1641 - val_accuracy: 0.6650
# Epoch 45/100
# 5/5 [==============================] - 0s 17ms/step - loss: 0.7161 - accuracy: 0.7809 - val_loss: 1.1564 - val_accuracy: 0.6800
# Epoch 46/100
# 5/5 [==============================] - 0s 19ms/step - loss: 0.6404 - accuracy: 0.7794 - val_loss: 1.1883 - val_accuracy: 0.6700
# Epoch 47/100
# 5/5 [==============================] - 0s 21ms/step - loss: 0.6769 - accuracy: 0.7851 - val_loss: 1.2232 - val_accuracy: 0.6700
# Epoch 48/100
# 5/5 [==============================] - 0s 19ms/step - loss: 0.6762 - accuracy: 0.7845 - val_loss: 1.1999 - val_accuracy: 0.6750
# Epoch 49/100
# 5/5 [==============================] - 0s 23ms/step - loss: 0.6535 - accuracy: 0.7905 - val_loss: 1.1969 - val_accuracy: 0.6400
# Epoch 50/100
# 5/5 [==============================] - 0s 23ms/step - loss: 0.6329 - accuracy: 0.7913 - val_loss: 1.2108 - val_accuracy: 0.6500
# Epoch 51/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.6104 - accuracy: 0.7933 - val_loss: 1.2071 - val_accuracy: 0.6500
# Epoch 52/100
# 5/5 [==============================] - 0s 29ms/step - loss: 0.6206 - accuracy: 0.8077 - val_loss: 1.2049 - val_accuracy: 0.6600
# Epoch 53/100
# 5/5 [==============================] - 0s 27ms/step - loss: 0.6473 - accuracy: 0.7984 - val_loss: 1.2352 - val_accuracy: 0.6500
# Epoch 54/100
# 5/5 [==============================] - 0s 18ms/step - loss: 0.5987 - accuracy: 0.8100 - val_loss: 1.2203 - val_accuracy: 0.6650
# Epoch 55/100
# 5/5 [==============================] - 0s 17ms/step - loss: 0.6378 - accuracy: 0.8004 - val_loss: 1.2179 - val_accuracy: 0.6550

# %%
test_loss, test_acc  = modelReg.evaluate(X_test, y_test, batch_size=128)
# Out:
# 2/2 [==============================] - 0s 2ms/step - loss: 1.1731 - accuracy: 0.6050

# %%
prediction = modelReg.predict(X_test)
y_pred = []
for index, y_encode in enumerate(prediction):
    y_pred.append(np.argmax(y_encode))
corrMatrix = confusion_matrix(y_test, y_pred)
fig, ax = plt.subplots(figsize=(10,10))

sns.heatmap(corrMatrix, annot = True, xticklabels=genres, yticklabels=genres, cbar=False).set_title("Dataset 1: Confusion Matrix: Model w/ Dropout and Reg")
# Out:
# Text(0.5, 1.0, 'Dataset 1: Confusion Matrix: Model w/ Dropout and Reg')

# %%
fig, ax = plt.subplots(1,2,figsize=(30,15))

ax[0].plot(history.history['accuracy'])
ax[0].plot(history.history['val_accuracy'])
ax[1].plot(history.history['loss'])
ax[1].plot(history.history['val_loss'])
ax[0].legend(["Accuracy", "Validation Accuracy"])
ax[1].legend(["Loss", "Validation Loss"])
ax[0].set_ylabel("Accuracy")
ax[0].set_xlabel("Epoch")
ax[0].set_title("Dataset 1: Model with Dropout and Reg: Accuracy")
ax[1].set_title("Dataset 1: Model with Dropout and Reg: Loss")
ax[1].set_ylabel("Loss")
ax[1].set_xlabel("Epoch")
# Out:
# Text(0.5, 0, 'Epoch')
