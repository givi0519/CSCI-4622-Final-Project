# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler

#Keras
import keras

# import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import seaborn as sns
import tensorflow as tf
from sklearn.utils import shuffle
from sklearn.metrics import confusion_matrix

plt.style.use('ggplot')
import librosa
from librosa import feature
from librosa import display
genres = [
    'blues', 'classical', 'country', 'disco', 'hiphop', 'jazz', 'metal', 'pop',
    'reggae', 'rock'
]

# %%
# load dataframe from csv
dfFeatures = pd.read_csv("music_features.csv")



# extract genres for labels
genreList = dfFeatures['genre']

# drop genres and filenames for training data
dfFeatures= dfFeatures.drop(columns = ['filename', 'genre'])

dfFeatures.head()
# Out:
#    chroma_stft_mean  spectral_centroid_mean  spectral_bandwidth_mean  \
# 0          0.342053             1782.622682              2020.556328
# 1          0.358000             1364.273766              1842.030467
# 2          0.382027             1521.556846              1736.799388
# 3          0.391765              947.018874              1427.836298
# 4          0.316456             2046.427867              1858.463045
#
#    rolloff_mean  zero_crossing_rate_mean       tempo  mfcc1_mean  mfcc2_mean  \
# 0   3845.075667                 0.080111  123.046875 -125.188171  120.222137
# 1   2976.303348                 0.055211  107.666016 -221.931198  131.147629
# 2   3028.062974                 0.070182  151.999081  -99.112022  141.554123
# 3   1863.946038                 0.030092   63.024009 -214.465668  156.586929
# 4   4005.025898                 0.116385  135.999178 -151.967178  115.340431
#
#    mfcc3_mean  mfcc4_mean  ...  mfcc11_mean  mfcc12_mean  mfcc13_mean  \
# 0  -18.358818   44.887314  ...    -8.861547     9.301556    -4.159669
# 1    0.490468   39.101952  ...    -3.123051     6.931743    -1.881995
# 2  -25.738703   34.465645  ...   -12.999936     4.544575    -8.695225
# 3    2.785257   26.750803  ...     2.481811     4.701363    -2.364664
# 4  -31.880495   23.762522  ...   -16.674786    -4.082293    -4.755991
#
#    mfcc14_mean  mfcc15_mean  mfcc16_mean  mfcc17_mean  mfcc18_mean  \
# 0     7.119120    -5.663028     0.530103    -2.870996     0.306077
# 1     4.951429    -4.531081    -0.463962     0.497853     0.039326
# 2    -2.315017    -8.144971     2.917833    -6.660074    -2.039234
# 3    -0.866406    -3.422017    -0.273013     0.231585     2.437521
# 4    -7.974098    -9.649985    -2.115260    -8.198335    -1.059961
#
#    mfcc19_mean  mfcc20_mean
# 0    -2.700369     2.370232
# 1    -1.083576    -0.112309
# 2    -2.045270    -2.697336
# 3     1.284240    -2.200283
# 4    -3.900608   -12.995133
#
# [5 rows x 26 columns]

# %%
# standardize data  
scaler = StandardScaler()
X = scaler.fit_transform(np.array(dfFeatures.iloc[:, :-1], dtype = float))

# encode labels 
encoder = LabelEncoder()
y = encoder.fit_transform(genreList)

# split into training and test data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state = 2)
X_train, X_val, y_train, y_val  = train_test_split(X_train, y_train, test_size=0.20, random_state=2)

# %%
# initialize keras network
model = keras.Sequential()
model.add(keras.layers.Dense(256, activation='relu', input_shape=(X_train.shape[1],)))
model.add(keras.layers.Dense(128, activation='relu'))
model.add(keras.layers.Dense(64, activation='relu'))
model.add(keras.layers.Dense(10, activation='softmax'))

# %%
# configure model for training
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
# train model

# https://www.geeksforgeeks.org/choose-optimal-number-of-epochs-to-train-a-neural-network-in-keras/
from keras import callbacks

#callback to prevent overfitting
earlystopping = callbacks.EarlyStopping(monitor ="val_loss", 
                                        mode ="min", patience = 10, 
                                        restore_best_weights = True)


history = model.fit(X_train,
                    y_train,
                    validation_data=(X_val, y_val),
                    epochs=100,
                    batch_size=128,
                    callbacks =[earlystopping])
# Out:
# Epoch 1/100
# 5/5 [==============================] - 2s 308ms/step - loss: 2.2829 - accuracy: 0.1263 - val_loss: 2.0447 - val_accuracy: 0.3750
# Epoch 2/100
# 5/5 [==============================] - 0s 20ms/step - loss: 1.9959 - accuracy: 0.3563 - val_loss: 1.8310 - val_accuracy: 0.3438
# Epoch 3/100
# 5/5 [==============================] - 0s 27ms/step - loss: 1.7980 - accuracy: 0.3541 - val_loss: 1.7079 - val_accuracy: 0.3500
# Epoch 4/100
# 5/5 [==============================] - 0s 16ms/step - loss: 1.6686 - accuracy: 0.3634 - val_loss: 1.6084 - val_accuracy: 0.3875
# Epoch 5/100
# 5/5 [==============================] - 0s 17ms/step - loss: 1.5222 - accuracy: 0.4755 - val_loss: 1.5179 - val_accuracy: 0.4625
# Epoch 6/100
# 5/5 [==============================] - 0s 20ms/step - loss: 1.4225 - accuracy: 0.5336 - val_loss: 1.4385 - val_accuracy: 0.4875
# Epoch 7/100
# 5/5 [==============================] - 0s 13ms/step - loss: 1.3073 - accuracy: 0.5624 - val_loss: 1.3784 - val_accuracy: 0.4750
# Epoch 8/100
# 5/5 [==============================] - 0s 17ms/step - loss: 1.2305 - accuracy: 0.5920 - val_loss: 1.3191 - val_accuracy: 0.4563
# Epoch 9/100
# 5/5 [==============================] - 0s 14ms/step - loss: 1.1248 - accuracy: 0.6265 - val_loss: 1.2805 - val_accuracy: 0.4938
# Epoch 10/100
# 5/5 [==============================] - 0s 15ms/step - loss: 1.0541 - accuracy: 0.6551 - val_loss: 1.2507 - val_accuracy: 0.5188
# Epoch 11/100
# 5/5 [==============================] - 0s 18ms/step - loss: 1.0159 - accuracy: 0.6873 - val_loss: 1.2123 - val_accuracy: 0.5437
# Epoch 12/100
# 5/5 [==============================] - 0s 16ms/step - loss: 0.9781 - accuracy: 0.6807 - val_loss: 1.1944 - val_accuracy: 0.5688
# Epoch 13/100
# 5/5 [==============================] - 0s 16ms/step - loss: 0.9027 - accuracy: 0.7454 - val_loss: 1.1907 - val_accuracy: 0.5750
# Epoch 14/100
# 5/5 [==============================] - 0s 19ms/step - loss: 0.8941 - accuracy: 0.7204 - val_loss: 1.1558 - val_accuracy: 0.5688
# Epoch 15/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.7821 - accuracy: 0.7860 - val_loss: 1.1549 - val_accuracy: 0.5875
# Epoch 16/100
# 5/5 [==============================] - 0s 16ms/step - loss: 0.7505 - accuracy: 0.7700 - val_loss: 1.1435 - val_accuracy: 0.5875
# Epoch 17/100
# 5/5 [==============================] - 0s 18ms/step - loss: 0.7426 - accuracy: 0.7687 - val_loss: 1.1165 - val_accuracy: 0.6062
# Epoch 18/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.6996 - accuracy: 0.7736 - val_loss: 1.1102 - val_accuracy: 0.6313
# Epoch 19/100
# 5/5 [==============================] - 0s 22ms/step - loss: 0.6747 - accuracy: 0.7870 - val_loss: 1.1158 - val_accuracy: 0.6187
# Epoch 20/100
# 5/5 [==============================] - 0s 19ms/step - loss: 0.6474 - accuracy: 0.7953 - val_loss: 1.0815 - val_accuracy: 0.6000
# Epoch 21/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.6044 - accuracy: 0.8262 - val_loss: 1.0942 - val_accuracy: 0.6000
# Epoch 22/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.5833 - accuracy: 0.8205 - val_loss: 1.0981 - val_accuracy: 0.6062
# Epoch 23/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.5088 - accuracy: 0.8605 - val_loss: 1.0716 - val_accuracy: 0.6250
# Epoch 24/100
# 5/5 [==============================] - 0s 17ms/step - loss: 0.5033 - accuracy: 0.8625 - val_loss: 1.0874 - val_accuracy: 0.6187
# Epoch 25/100
# 5/5 [==============================] - 0s 17ms/step - loss: 0.4847 - accuracy: 0.8756 - val_loss: 1.0986 - val_accuracy: 0.6062
# Epoch 26/100
# 5/5 [==============================] - 0s 16ms/step - loss: 0.4907 - accuracy: 0.8576 - val_loss: 1.0797 - val_accuracy: 0.6187
# Epoch 27/100
# 5/5 [==============================] - 0s 12ms/step - loss: 0.4616 - accuracy: 0.8660 - val_loss: 1.0819 - val_accuracy: 0.6187
# Epoch 28/100
# 5/5 [==============================] - 0s 17ms/step - loss: 0.4421 - accuracy: 0.8702 - val_loss: 1.0938 - val_accuracy: 0.6375
# Epoch 29/100
# 5/5 [==============================] - 0s 18ms/step - loss: 0.4044 - accuracy: 0.9042 - val_loss: 1.1097 - val_accuracy: 0.6187
# Epoch 30/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.3963 - accuracy: 0.8883 - val_loss: 1.1120 - val_accuracy: 0.6187
# Epoch 31/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.3519 - accuracy: 0.9264 - val_loss: 1.1132 - val_accuracy: 0.6125
# Epoch 32/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.3569 - accuracy: 0.9174 - val_loss: 1.1386 - val_accuracy: 0.6250
# Epoch 33/100
# 5/5 [==============================] - 0s 16ms/step - loss: 0.3474 - accuracy: 0.9054 - val_loss: 1.1237 - val_accuracy: 0.6375

# %%
test_loss, test_acc  = model.evaluate(X_test, y_test, batch_size=128)
# Out:
# 2/2 [==============================] - 0s 2ms/step - loss: 1.3124 - accuracy: 0.5600

# %%
prediction = model.predict(X_test)
y_pred = []
for index, y_encode in enumerate(prediction):
    y_pred.append(np.argmax(y_encode))
corrMatrix = confusion_matrix(y_test, y_pred)
fig, ax = plt.subplots(figsize=(10,10))

sns.heatmap(corrMatrix, annot = True, xticklabels=genres, yticklabels=genres, cbar=False)
# Out:
# <AxesSubplot:>

# %%
fig, ax = plt.subplots(1,2,figsize=(30,15))

ax[0].plot(history.history['accuracy'])
ax[0].plot(history.history['val_accuracy'])
ax[1].plot(history.history['loss'])
ax[1].plot(history.history['val_loss'])
ax[0].legend(["Accuracy", "Validation Accuracy"])
ax[1].legend(["Loss", "Validation Loss"])
ax[0].set_ylabel("Accuracy")
ax[0].set_xlabel("Epoch")

ax[1].set_ylabel("Loss")
ax[1].set_xlabel("Epoch")
# Out:
# Text(0.5, 0, 'Epoch')

# %%
# initialize keras network
modeldropout = keras.Sequential()
modeldropout.add(keras.layers.Dense(256, activation='relu', input_shape=(X_train.shape[1],)))
modeldropout.add(keras.layers.Dropout(0.2))
modeldropout.add(keras.layers.Dense(128, activation='relu'))
modeldropout.add(keras.layers.Dropout(0.2))
modeldropout.add(keras.layers.Dense(64, activation='relu'))
modeldropout.add(keras.layers.Dropout(0.2))
modeldropout.add(keras.layers.Dense(10, activation='softmax'))

# %%
modeldropout.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
history = modeldropout.fit(X_train,
                    y_train,
                    epochs=100,
                    callbacks =[earlystopping],
                    validation_data=(X_val, y_val),
                    batch_size=128)
# Out:
# Epoch 1/100
# 5/5 [==============================] - 1s 62ms/step - loss: 2.3158 - accuracy: 0.1280 - val_loss: 2.1495 - val_accuracy: 0.3125
# Epoch 2/100
# 5/5 [==============================] - 0s 20ms/step - loss: 2.1517 - accuracy: 0.2722 - val_loss: 2.0029 - val_accuracy: 0.3500
# Epoch 3/100
# 5/5 [==============================] - 0s 28ms/step - loss: 1.9823 - accuracy: 0.3550 - val_loss: 1.8573 - val_accuracy: 0.3562
# Epoch 4/100
# 5/5 [==============================] - 0s 22ms/step - loss: 1.8790 - accuracy: 0.3905 - val_loss: 1.7443 - val_accuracy: 0.3562
# Epoch 5/100
# 5/5 [==============================] - 0s 20ms/step - loss: 1.7559 - accuracy: 0.4058 - val_loss: 1.6616 - val_accuracy: 0.4062
# Epoch 6/100
# 5/5 [==============================] - 0s 21ms/step - loss: 1.6776 - accuracy: 0.4202 - val_loss: 1.5927 - val_accuracy: 0.4000
# Epoch 7/100
# 5/5 [==============================] - 0s 14ms/step - loss: 1.6370 - accuracy: 0.4395 - val_loss: 1.5237 - val_accuracy: 0.4187
# Epoch 8/100
# 5/5 [==============================] - 0s 13ms/step - loss: 1.5416 - accuracy: 0.4944 - val_loss: 1.4703 - val_accuracy: 0.4437
# Epoch 9/100
# 5/5 [==============================] - 0s 15ms/step - loss: 1.4073 - accuracy: 0.5085 - val_loss: 1.4326 - val_accuracy: 0.4250
# Epoch 10/100
# 5/5 [==============================] - 0s 14ms/step - loss: 1.3655 - accuracy: 0.5269 - val_loss: 1.3974 - val_accuracy: 0.4437
# Epoch 11/100
# 5/5 [==============================] - 0s 22ms/step - loss: 1.3414 - accuracy: 0.5362 - val_loss: 1.3700 - val_accuracy: 0.4375
# Epoch 12/100
# 5/5 [==============================] - 0s 22ms/step - loss: 1.3417 - accuracy: 0.5549 - val_loss: 1.3532 - val_accuracy: 0.4563
# Epoch 13/100
# 5/5 [==============================] - 0s 18ms/step - loss: 1.2775 - accuracy: 0.5735 - val_loss: 1.3214 - val_accuracy: 0.4750
# Epoch 14/100
# 5/5 [==============================] - 0s 16ms/step - loss: 1.2260 - accuracy: 0.6010 - val_loss: 1.2985 - val_accuracy: 0.4875
# Epoch 15/100
# 5/5 [==============================] - 0s 17ms/step - loss: 1.2318 - accuracy: 0.5771 - val_loss: 1.2718 - val_accuracy: 0.5063
# Epoch 16/100
# 5/5 [==============================] - 0s 18ms/step - loss: 1.2002 - accuracy: 0.5727 - val_loss: 1.2505 - val_accuracy: 0.5312
# Epoch 17/100
# 5/5 [==============================] - 0s 18ms/step - loss: 1.1183 - accuracy: 0.6406 - val_loss: 1.2278 - val_accuracy: 0.5500
# Epoch 18/100
# 5/5 [==============================] - 0s 19ms/step - loss: 1.0980 - accuracy: 0.6352 - val_loss: 1.2046 - val_accuracy: 0.5688
# Epoch 19/100
# 5/5 [==============================] - 0s 18ms/step - loss: 1.0518 - accuracy: 0.6447 - val_loss: 1.1972 - val_accuracy: 0.5750
# Epoch 20/100
# 5/5 [==============================] - 0s 26ms/step - loss: 1.0256 - accuracy: 0.6654 - val_loss: 1.1945 - val_accuracy: 0.5750
# Epoch 21/100
# 5/5 [==============================] - 0s 21ms/step - loss: 1.0407 - accuracy: 0.6729 - val_loss: 1.1670 - val_accuracy: 0.5750
# Epoch 22/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.9586 - accuracy: 0.7069 - val_loss: 1.1639 - val_accuracy: 0.5938
# Epoch 23/100
# 5/5 [==============================] - 0s 23ms/step - loss: 1.0051 - accuracy: 0.6430 - val_loss: 1.1544 - val_accuracy: 0.5938
# Epoch 24/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.9583 - accuracy: 0.6656 - val_loss: 1.1402 - val_accuracy: 0.6000
# Epoch 25/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.9520 - accuracy: 0.6875 - val_loss: 1.1270 - val_accuracy: 0.6000
# Epoch 26/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.9346 - accuracy: 0.6935 - val_loss: 1.1213 - val_accuracy: 0.6125
# Epoch 27/100
# 5/5 [==============================] - 0s 17ms/step - loss: 0.9370 - accuracy: 0.6974 - val_loss: 1.1329 - val_accuracy: 0.6125
# Epoch 28/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.8759 - accuracy: 0.6978 - val_loss: 1.1400 - val_accuracy: 0.6000
# Epoch 29/100
# 5/5 [==============================] - 0s 18ms/step - loss: 0.8769 - accuracy: 0.7525 - val_loss: 1.1269 - val_accuracy: 0.6125
# Epoch 30/100
# 5/5 [==============================] - 0s 21ms/step - loss: 0.8648 - accuracy: 0.6919 - val_loss: 1.1261 - val_accuracy: 0.6250
# Epoch 31/100
# 5/5 [==============================] - 0s 22ms/step - loss: 0.8565 - accuracy: 0.7133 - val_loss: 1.1072 - val_accuracy: 0.6375
# Epoch 32/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.7536 - accuracy: 0.7423 - val_loss: 1.1040 - val_accuracy: 0.6250
# Epoch 33/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.8487 - accuracy: 0.7156 - val_loss: 1.1029 - val_accuracy: 0.6187
# Epoch 34/100
# 5/5 [==============================] - 0s 19ms/step - loss: 0.8328 - accuracy: 0.7199 - val_loss: 1.0802 - val_accuracy: 0.6313
# Epoch 35/100
# 5/5 [==============================] - 0s 25ms/step - loss: 0.7983 - accuracy: 0.7211 - val_loss: 1.0978 - val_accuracy: 0.6187
# Epoch 36/100
# 5/5 [==============================] - 0s 17ms/step - loss: 0.7999 - accuracy: 0.7357 - val_loss: 1.0984 - val_accuracy: 0.6062
# Epoch 37/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.7431 - accuracy: 0.7500 - val_loss: 1.0930 - val_accuracy: 0.6250
# Epoch 38/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.7431 - accuracy: 0.7396 - val_loss: 1.0991 - val_accuracy: 0.6187
# Epoch 39/100
# 5/5 [==============================] - 0s 20ms/step - loss: 0.6994 - accuracy: 0.7699 - val_loss: 1.0813 - val_accuracy: 0.6375
# Epoch 40/100
# 5/5 [==============================] - 0s 16ms/step - loss: 0.7004 - accuracy: 0.7919 - val_loss: 1.0733 - val_accuracy: 0.6562
# Epoch 41/100
# 5/5 [==============================] - 0s 16ms/step - loss: 0.7328 - accuracy: 0.7683 - val_loss: 1.0755 - val_accuracy: 0.6625
# Epoch 42/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.7351 - accuracy: 0.7586 - val_loss: 1.0723 - val_accuracy: 0.6812
# Epoch 43/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.6554 - accuracy: 0.7662 - val_loss: 1.0843 - val_accuracy: 0.6500
# Epoch 44/100
# 5/5 [==============================] - 0s 21ms/step - loss: 0.7036 - accuracy: 0.7698 - val_loss: 1.0740 - val_accuracy: 0.6562
# Epoch 45/100
# 5/5 [==============================] - 0s 19ms/step - loss: 0.6537 - accuracy: 0.7740 - val_loss: 1.0874 - val_accuracy: 0.6500
# Epoch 46/100
# 5/5 [==============================] - 0s 17ms/step - loss: 0.6525 - accuracy: 0.7708 - val_loss: 1.0818 - val_accuracy: 0.6500
# Epoch 47/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.6243 - accuracy: 0.7942 - val_loss: 1.0841 - val_accuracy: 0.6625
# Epoch 48/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.5968 - accuracy: 0.7970 - val_loss: 1.0822 - val_accuracy: 0.6438
# Epoch 49/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.6300 - accuracy: 0.7966 - val_loss: 1.0839 - val_accuracy: 0.6687
# Epoch 50/100
# 5/5 [==============================] - 0s 20ms/step - loss: 0.6575 - accuracy: 0.7893 - val_loss: 1.0773 - val_accuracy: 0.6625
# Epoch 51/100
# 5/5 [==============================] - 0s 17ms/step - loss: 0.6806 - accuracy: 0.7743 - val_loss: 1.1053 - val_accuracy: 0.6375
# Epoch 52/100
# 5/5 [==============================] - 0s 17ms/step - loss: 0.5887 - accuracy: 0.7944 - val_loss: 1.1093 - val_accuracy: 0.6375

# %%
test_loss, test_acc  = modeldropout.evaluate(X_test, y_test, batch_size=128)
# Out:
# 2/2 [==============================] - 0s 2ms/step - loss: 1.3509 - accuracy: 0.5750

# %%
prediction = modeldropout.predict(X_test)
y_pred = []
for index, y_encode in enumerate(prediction):
    y_pred.append(np.argmax(y_encode))
corrMatrix = confusion_matrix(y_test, y_pred)
fig, ax = plt.subplots(figsize=(10,10))

sns.heatmap(corrMatrix, annot = True, xticklabels=genres, yticklabels=genres, cbar=False)
# Out:
# <AxesSubplot:>

# %%
fig, ax = plt.subplots(1,2,figsize=(30,15))

ax[0].plot(history.history['accuracy'])
ax[0].plot(history.history['val_accuracy'])
ax[1].plot(history.history['loss'])
ax[1].plot(history.history['val_loss'])
ax[0].legend(["Accuracy", "Validation Accuracy"])
ax[1].legend(["Loss", "Validation Loss"])
ax[0].set_ylabel("Accuracy")
ax[0].set_xlabel("Epoch")

ax[1].set_ylabel("Loss")
ax[1].set_xlabel("Epoch")
# Out:
# Text(0.5, 0, 'Epoch')

# %%
modelReg = keras.Sequential()
modelReg.add(keras.layers.Dense(256, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(1e-4), input_shape=(X_train.shape[1],)))
modelReg.add(keras.layers.Dropout(0.2))
modelReg.add(keras.layers.Dense(128, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(1e-4)))
modelReg.add(keras.layers.Dropout(0.2))
modelReg.add(keras.layers.Dense(64, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(1e-4)))
modelReg.add(keras.layers.Dropout(0.2))
modelReg.add(keras.layers.Dense(10, activation='softmax', activity_regularizer=tf.keras.regularizers.l2(1e-4)))

# %%
modelReg.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
history = modelReg.fit(X_train,
                    y_train,
                    epochs=100,
                    callbacks =[earlystopping],
                    validation_data=(X_val, y_val),
                    batch_size=128)
# Out:
# Epoch 1/100
# 5/5 [==============================] - 1s 67ms/step - loss: 2.3628 - accuracy: 0.1087 - val_loss: 2.1685 - val_accuracy: 0.3187
# Epoch 2/100
# 5/5 [==============================] - 0s 14ms/step - loss: 2.1375 - accuracy: 0.2770 - val_loss: 2.0154 - val_accuracy: 0.3375
# Epoch 3/100
# 5/5 [==============================] - 0s 17ms/step - loss: 2.0047 - accuracy: 0.3135 - val_loss: 1.8974 - val_accuracy: 0.3500
# Epoch 4/100
# 5/5 [==============================] - 0s 16ms/step - loss: 1.8651 - accuracy: 0.3787 - val_loss: 1.7908 - val_accuracy: 0.3875
# Epoch 5/100
# 5/5 [==============================] - 0s 18ms/step - loss: 1.7429 - accuracy: 0.3920 - val_loss: 1.6924 - val_accuracy: 0.4250
# Epoch 6/100
# 5/5 [==============================] - 0s 15ms/step - loss: 1.6919 - accuracy: 0.4293 - val_loss: 1.6063 - val_accuracy: 0.4125
# Epoch 7/100
# 5/5 [==============================] - 0s 19ms/step - loss: 1.5386 - accuracy: 0.4916 - val_loss: 1.5412 - val_accuracy: 0.4125
# Epoch 8/100
# 5/5 [==============================] - 0s 15ms/step - loss: 1.5371 - accuracy: 0.4626 - val_loss: 1.5031 - val_accuracy: 0.4313
# Epoch 9/100
# 5/5 [==============================] - 0s 15ms/step - loss: 1.4404 - accuracy: 0.4976 - val_loss: 1.4599 - val_accuracy: 0.4437
# Epoch 10/100
# 5/5 [==============================] - 0s 15ms/step - loss: 1.3777 - accuracy: 0.5635 - val_loss: 1.4240 - val_accuracy: 0.4563
# Epoch 11/100
# 5/5 [==============================] - 0s 15ms/step - loss: 1.3510 - accuracy: 0.5268 - val_loss: 1.4070 - val_accuracy: 0.4500
# Epoch 12/100
# 5/5 [==============================] - 0s 15ms/step - loss: 1.3470 - accuracy: 0.5395 - val_loss: 1.3852 - val_accuracy: 0.4688
# Epoch 13/100
# 5/5 [==============================] - 0s 14ms/step - loss: 1.2713 - accuracy: 0.5807 - val_loss: 1.3562 - val_accuracy: 0.4750
# Epoch 14/100
# 5/5 [==============================] - 0s 13ms/step - loss: 1.2799 - accuracy: 0.6022 - val_loss: 1.3212 - val_accuracy: 0.4938
# Epoch 15/100
# 5/5 [==============================] - 0s 14ms/step - loss: 1.1721 - accuracy: 0.6540 - val_loss: 1.3039 - val_accuracy: 0.5063
# Epoch 16/100
# 5/5 [==============================] - 0s 13ms/step - loss: 1.1774 - accuracy: 0.6176 - val_loss: 1.3013 - val_accuracy: 0.5250
# Epoch 17/100
# 5/5 [==============================] - 0s 15ms/step - loss: 1.1900 - accuracy: 0.5879 - val_loss: 1.2955 - val_accuracy: 0.5000
# Epoch 18/100
# 5/5 [==============================] - 0s 15ms/step - loss: 1.0880 - accuracy: 0.6570 - val_loss: 1.2788 - val_accuracy: 0.5188
# Epoch 19/100
# 5/5 [==============================] - 0s 15ms/step - loss: 1.0932 - accuracy: 0.6494 - val_loss: 1.2460 - val_accuracy: 0.5188
# Epoch 20/100
# 5/5 [==============================] - 0s 15ms/step - loss: 1.0918 - accuracy: 0.6464 - val_loss: 1.2438 - val_accuracy: 0.5250
# Epoch 21/100
# 5/5 [==============================] - 0s 17ms/step - loss: 1.0343 - accuracy: 0.6646 - val_loss: 1.2335 - val_accuracy: 0.5312
# Epoch 22/100
# 5/5 [==============================] - 0s 19ms/step - loss: 0.9701 - accuracy: 0.6814 - val_loss: 1.2148 - val_accuracy: 0.5625
# Epoch 23/100
# 5/5 [==============================] - 0s 16ms/step - loss: 1.0446 - accuracy: 0.6748 - val_loss: 1.2014 - val_accuracy: 0.5437
# Epoch 24/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.9808 - accuracy: 0.6862 - val_loss: 1.1967 - val_accuracy: 0.5750
# Epoch 25/100
# 5/5 [==============================] - 0s 12ms/step - loss: 0.9635 - accuracy: 0.6810 - val_loss: 1.1830 - val_accuracy: 0.5750
# Epoch 26/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.9606 - accuracy: 0.6999 - val_loss: 1.1629 - val_accuracy: 0.5750
# Epoch 27/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.9768 - accuracy: 0.7137 - val_loss: 1.1506 - val_accuracy: 0.5875
# Epoch 28/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.9235 - accuracy: 0.7275 - val_loss: 1.1465 - val_accuracy: 0.6000
# Epoch 29/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.9191 - accuracy: 0.7052 - val_loss: 1.1382 - val_accuracy: 0.6500
# Epoch 30/100
# 5/5 [==============================] - 0s 16ms/step - loss: 0.9041 - accuracy: 0.7181 - val_loss: 1.1325 - val_accuracy: 0.5938
# Epoch 31/100
# 5/5 [==============================] - 0s 17ms/step - loss: 0.9086 - accuracy: 0.7039 - val_loss: 1.1450 - val_accuracy: 0.6000
# Epoch 32/100
# 5/5 [==============================] - 0s 16ms/step - loss: 0.8855 - accuracy: 0.7464 - val_loss: 1.1545 - val_accuracy: 0.5875
# Epoch 33/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.8444 - accuracy: 0.7309 - val_loss: 1.1402 - val_accuracy: 0.6125
# Epoch 34/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.8418 - accuracy: 0.7386 - val_loss: 1.1152 - val_accuracy: 0.6125
# Epoch 35/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.8376 - accuracy: 0.7361 - val_loss: 1.1193 - val_accuracy: 0.6000
# Epoch 36/100
# 5/5 [==============================] - 0s 18ms/step - loss: 0.8147 - accuracy: 0.7464 - val_loss: 1.1447 - val_accuracy: 0.6000
# Epoch 37/100
# 5/5 [==============================] - 0s 16ms/step - loss: 0.8169 - accuracy: 0.7261 - val_loss: 1.1134 - val_accuracy: 0.6187
# Epoch 38/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.7544 - accuracy: 0.7647 - val_loss: 1.0986 - val_accuracy: 0.6187
# Epoch 39/100
# 5/5 [==============================] - 0s 17ms/step - loss: 0.8046 - accuracy: 0.7542 - val_loss: 1.1325 - val_accuracy: 0.6062
# Epoch 40/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.7666 - accuracy: 0.7662 - val_loss: 1.1287 - val_accuracy: 0.6250
# Epoch 41/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.7734 - accuracy: 0.7655 - val_loss: 1.1135 - val_accuracy: 0.6187
# Epoch 42/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.7720 - accuracy: 0.7625 - val_loss: 1.1259 - val_accuracy: 0.6375
# Epoch 43/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.6928 - accuracy: 0.7766 - val_loss: 1.1343 - val_accuracy: 0.6125
# Epoch 44/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.7126 - accuracy: 0.7713 - val_loss: 1.1085 - val_accuracy: 0.6438
# Epoch 45/100
# 5/5 [==============================] - 0s 12ms/step - loss: 0.6854 - accuracy: 0.7661 - val_loss: 1.1042 - val_accuracy: 0.6187
# Epoch 46/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.6367 - accuracy: 0.8053 - val_loss: 1.1085 - val_accuracy: 0.6125
# Epoch 47/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.6775 - accuracy: 0.7854 - val_loss: 1.1295 - val_accuracy: 0.6250
# Epoch 48/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.7205 - accuracy: 0.7792 - val_loss: 1.1436 - val_accuracy: 0.6313

# %%
test_loss, test_acc  = modelReg.evaluate(X_test, y_test, batch_size=128)
# Out:
# 2/2 [==============================] - 0s 8ms/step - loss: 1.3942 - accuracy: 0.5500

# %%
prediction = modelReg.predict(X_test)
y_pred = []
for index, y_encode in enumerate(prediction):
    y_pred.append(np.argmax(y_encode))
corrMatrix = confusion_matrix(y_test, y_pred)
fig, ax = plt.subplots(figsize=(10,10))

sns.heatmap(corrMatrix, annot = True, xticklabels=genres, yticklabels=genres, cbar=False)
# Out:
# <AxesSubplot:>

# %%
fig, ax = plt.subplots(1,2,figsize=(30,15))

ax[0].plot(history.history['accuracy'])
ax[0].plot(history.history['val_accuracy'])
ax[1].plot(history.history['loss'])
ax[1].plot(history.history['val_loss'])
ax[0].legend(["Accuracy", "Validation Accuracy"])
ax[1].legend(["Loss", "Validation Loss"])
ax[0].set_ylabel("Accuracy")
ax[0].set_xlabel("Epoch")

ax[1].set_ylabel("Loss")
ax[1].set_xlabel("Epoch")
# Out:
# Text(0.5, 0, 'Epoch')
