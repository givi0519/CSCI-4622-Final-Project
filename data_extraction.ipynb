# %%
# Music Classification - CSCI 4622 Final Project
# Giovanni Visco, Ishan Kumar, Avnish Asthana, Dhruv Patel

# import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import seaborn as sns
from sklearn.utils import shuffle


plt.style.use('ggplot')
import librosa
from librosa import feature
from librosa import display
genres = [
    'blues', 'classical', 'country', 'disco', 'hiphop', 'jazz', 'metal', 'pop',
    'reggae', 'rock'
]

# %%
# list data
for dirname, _, filenames in os.walk('./data/'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# ./data/blues\blues.00000.au
# ./data/blues\blues.00001.au
# ./data/blues\blues.00002.au
# ./data/blues\blues.00003.au
# ./data/blues\blues.00004.au
# ./data/blues\blues.00005.au
# ./data/blues\blues.00006.au
# ./data/blues\blues.00007.au
# ./data/blues\blues.00008.au
# ./data/blues\blues.00009.au
# ./data/blues\blues.00010.au
# ./data/blues\blues.00011.au
# ./data/blues\blues.00012.au
# ./data/blues\blues.00013.au
# ./data/blues\blues.00014.au
# ./data/blues\blues.00015.au
# ./data/blues\blues.00016.au
# ./data/blues\blues.00017.au
# ./data/blues\blues.00018.au
# ./data/blues\blues.00019.au
# ./data/blues\blues.00020.au
# ./data/blues\blues.00021.au
# ./data/blues\blues.00022.au
# ./data/blues\blues.00023.au
# ./data/blues\blues.00024.au
# ./data/blues\blues.00025.au
# ./data/blues\blues.00026.au
# ./data/blues\blues.00027.au
# ./data/blues\blues.00028.au
# ./data/blues\blues.00029.au
# ./data/blues\blues.00030.au
# ./data/blues\blues.00031.au
# ./data/blues\blues.00032.au
# ./data/blues\blues.00033.au
# ./data/blues\blues.00034.au
# ./data/blues\blues.00035.au
# ./data/blues\blues.00036.au
# ./data/blues\blues.00037.au
# ./data/blues\blues.00038.au
# ./data/blues\blues.00039.au
# ./data/blues\blues.00040.au
# ./data/blues\blues.00041.au
# ./data/blues\blues.00042.au
# ./data/blues\blues.00043.au
# ./data/blues\blues.00044.au
# ./data/blues\blues.00045.au
# ./data/blues\blues.00046.au
# ./data/blues\blues.00047.au
# ./data/blues\blues.00048.au
# ./data/blues\blues.00049.au
# ./data/blues\blues.00050.au
# ./data/blues\blues.00051.au
# ./data/blues\blues.00052.au
# ./data/blues\blues.00053.au
# ./data/blues\blues.00054.au
# ./data/blues\blues.00055.au
# ./data/blues\blues.00056.au
# ./data/blues\blues.00057.au
# ./data/blues\blues.00058.au
# ./data/blues\blues.00059.au
# ./data/blues\blues.00060.au
# ./data/blues\blues.00061.au
# ./data/blues\blues.00062.au
# ./data/blues\blues.00063.au
# ./data/blues\blues.00064.au
# ./data/blues\blues.00065.au
# ./data/blues\blues.00066.au
# ./data/blues\blues.00067.au
# ./data/blues\blues.00068.au
# ./data/blues\blues.00069.au
# ./data/blues\blues.00070.au
# ./data/blues\blues.00071.au
# ./data/blues\blues.00072.au
# ./data/blues\blues.00073.au
# ./data/blues\blues.00074.au
# ./data/blues\blues.00075.au
# ./data/blues\blues.00076.au
# ./data/blues\blues.00077.au
# ./data/blues\blues.00078.au
# ./data/blues\blues.00079.au
# ./data/blues\blues.00080.au
# ./data/blues\blues.00081.au
# ./data/blues\blues.00082.au
# ./data/blues\blues.00083.au
# ./data/blues\blues.00084.au
# ./data/blues\blues.00085.au
# ./data/blues\blues.00086.au
# ./data/blues\blues.00087.au
# ./data/blues\blues.00088.au
# ./data/blues\blues.00089.au
# ./data/blues\blues.00090.au
# ./data/blues\blues.00091.au
# ./data/blues\blues.00092.au
# ./data/blues\blues.00093.au
# ./data/blues\blues.00094.au
# ./data/blues\blues.00095.au
# ./data/blues\blues.00096.au
# ./data/blues\blues.00097.au
# ./data/blues\blues.00098.au
# ./data/blues\blues.00099.au
# ./data/classical\classical.00000.au
# ./data/classical\classical.00001.au
# ./data/classical\classical.00002.au
# ./data/classical\classical.00003.au
# ./data/classical\classical.00004.au
# ./data/classical\classical.00005.au
# ./data/classical\classical.00006.au
# ./data/classical\classical.00007.au
# ./data/classical\classical.00008.au
# ./data/classical\classical.00009.au
# ./data/classical\classical.00010.au
# ./data/classical\classical.00011.au
# ./data/classical\classical.00012.au
# ./data/classical\classical.00013.au
# ./data/classical\classical.00014.au
# ./data/classical\classical.00015.au
# ./data/classical\classical.00016.au
# ./data/classical\classical.00017.au
# ./data/classical\classical.00018.au
# ./data/classical\classical.00019.au
# ./data/classical\classical.00020.au
# ./data/classical\classical.00021.au
# ./data/classical\classical.00022.au
# ./data/classical\classical.00023.au
# ./data/classical\classical.00024.au
# ./data/classical\classical.00025.au
# ./data/classical\classical.00026.au
# ./data/classical\classical.00027.au
# ./data/classical\classical.00028.au
# ./data/classical\classical.00029.au
# ./data/classical\classical.00030.au
# ./data/classical\classical.00031.au
# ./data/classical\classical.00032.au
# ./data/classical\classical.00033.au
# ./data/classical\classical.00034.au
# ./data/classical\classical.00035.au
# ./data/classical\classical.00036.au
# ./data/classical\classical.00037.au
# ./data/classical\classical.00038.au
# ./data/classical\classical.00039.au
# ./data/classical\classical.00040.au
# ./data/classical\classical.00041.au
# ./data/classical\classical.00042.au
# ./data/classical\classical.00043.au
# ./data/classical\classical.00044.au
# ./data/classical\classical.00045.au
# ./data/classical\classical.00046.au
# ./data/classical\classical.00047.au
# ./data/classical\classical.00048.au
# ./data/classical\classical.00049.au
# ./data/classical\classical.00050.au
# ./data/classical\classical.00051.au
# ./data/classical\classical.00052.au
# ./data/classical\classical.00053.au
# ./data/classical\classical.00054.au
# ./data/classical\classical.00055.au
# ./data/classical\classical.00056.au
# ./data/classical\classical.00057.au
# ./data/classical\classical.00058.au
# ./data/classical\classical.00059.au
# ./data/classical\classical.00060.au
# ./data/classical\classical.00061.au
# ./data/classical\classical.00062.au
# ./data/classical\classical.00063.au
# ./data/classical\classical.00064.au
# ./data/classical\classical.00065.au
# ./data/classical\classical.00066.au
# ./data/classical\classical.00067.au
# ./data/classical\classical.00068.au
# ./data/classical\classical.00069.au
# ./data/classical\classical.00070.au
# ./data/classical\classical.00071.au
# ./data/classical\classical.00072.au
# ./data/classical\classical.00073.au
# ./data/classical\classical.00074.au
# ./data/classical\classical.00075.au
# ./data/classical\classical.00076.au
# ./data/classical\classical.00077.au
# ./data/classical\classical.00078.au
# ./data/classical\classical.00079.au
# ./data/classical\classical.00080.au
# ./data/classical\classical.00081.au
# ./data/classical\classical.00082.au
# ./data/classical\classical.00083.au
# ./data/classical\classical.00084.au
# ./data/classical\classical.00085.au
# ./data/classical\classical.00086.au
# ./data/classical\classical.00087.au
# ./data/classical\classical.00088.au
# ./data/classical\classical.00089.au
# ./data/classical\classical.00090.au
# ./data/classical\classical.00091.au
# ./data/classical\classical.00092.au
# ./data/classical\classical.00093.au
# ./data/classical\classical.00094.au
# ./data/classical\classical.00095.au
# ./data/classical\classical.00096.au
# ./data/classical\classical.00097.au
# ./data/classical\classical.00098.au
# ./data/classical\classical.00099.au
# ./data/country\country.00000.au
# ./data/country\country.00001.au
# ./data/country\country.00002.au
# ./data/country\country.00003.au
# ./data/country\country.00004.au
# ./data/country\country.00005.au
# ./data/country\country.00006.au
# ./data/country\country.00007.au
# ./data/country\country.00008.au
# ./data/country\country.00009.au
# ./data/country\country.00010.au
# ./data/country\country.00011.au
# ./data/country\country.00012.au
# ./data/country\country.00013.au
# ./data/country\country.00014.au
# ./data/country\country.00015.au
# ./data/country\country.00016.au
# ./data/country\country.00017.au
# ./data/country\country.00018.au
# ./data/country\country.00019.au
# ./data/country\country.00020.au
# ./data/country\country.00021.au
# ./data/country\country.00022.au
# ./data/country\country.00023.au
# ./data/country\country.00024.au
# ./data/country\country.00025.au
# ./data/country\country.00026.au
# ./data/country\country.00027.au
# ./data/country\country.00028.au
# ./data/country\country.00029.au
# ./data/country\country.00030.au
# ./data/country\country.00031.au
# ./data/country\country.00032.au
# ./data/country\country.00033.au
# ./data/country\country.00034.au
# ./data/country\country.00035.au
# ./data/country\country.00036.au
# ./data/country\country.00037.au
# ./data/country\country.00038.au
# ./data/country\country.00039.au
# ./data/country\country.00040.au
# ./data/country\country.00041.au
# ./data/country\country.00042.au
# ./data/country\country.00043.au
# ./data/country\country.00044.au
# ./data/country\country.00045.au
# ./data/country\country.00046.au
# ./data/country\country.00047.au
# ./data/country\country.00048.au
# ./data/country\country.00049.au
# ./data/country\country.00050.au
# ./data/country\country.00051.au
# ./data/country\country.00052.au
# ./data/country\country.00053.au
# ./data/country\country.00054.au
# ./data/country\country.00055.au
# ./data/country\country.00056.au
# ./data/country\country.00057.au
# ./data/country\country.00058.au
# ./data/country\country.00059.au
# ./data/country\country.00060.au
# ./data/country\country.00061.au
# ./data/country\country.00062.au
# ./data/country\country.00063.au
# ./data/country\country.00064.au
# ./data/country\country.00065.au
# ./data/country\country.00066.au
# ./data/country\country.00067.au
# ./data/country\country.00068.au
# ./data/country\country.00069.au
# ./data/country\country.00070.au
# ./data/country\country.00071.au
# ./data/country\country.00072.au
# ./data/country\country.00073.au
# ./data/country\country.00074.au
# ./data/country\country.00075.au
# ./data/country\country.00076.au
# ./data/country\country.00077.au
# ./data/country\country.00078.au
# ./data/country\country.00079.au
# ./data/country\country.00080.au
# ./data/country\country.00081.au
# ./data/country\country.00082.au
# ./data/country\country.00083.au
# ./data/country\country.00084.au
# ./data/country\country.00085.au
# ./data/country\country.00086.au
# ./data/country\country.00087.au
# ./data/country\country.00088.au
# ./data/country\country.00089.au
# ./data/country\country.00090.au
# ./data/country\country.00091.au
# ./data/country\country.00092.au
# ./data/country\country.00093.au
# ./data/country\country.00094.au
# ./data/country\country.00095.au
# ./data/country\country.00096.au
# ./data/country\country.00097.au
# ./data/country\country.00098.au
# ./data/country\country.00099.au
# ./data/disco\disco.00000.au
# ./data/disco\disco.00001.au
# ./data/disco\disco.00002.au
# ./data/disco\disco.00003.au
# ./data/disco\disco.00004.au
# ./data/disco\disco.00005.au
# ./data/disco\disco.00006.au
# ./data/disco\disco.00007.au
# ./data/disco\disco.00008.au
# ./data/disco\disco.00009.au
# ./data/disco\disco.00010.au
# ./data/disco\disco.00011.au
# ./data/disco\disco.00012.au
# ./data/disco\disco.00013.au
# ./data/disco\disco.00014.au
# ./data/disco\disco.00015.au
# ./data/disco\disco.00016.au
# ./data/disco\disco.00017.au
# ./data/disco\disco.00018.au
# ./data/disco\disco.00019.au
# ./data/disco\disco.00020.au
# ./data/disco\disco.00021.au
# ./data/disco\disco.00022.au
# ./data/disco\disco.00023.au
# ./data/disco\disco.00024.au
# ./data/disco\disco.00025.au
# ./data/disco\disco.00026.au
# ./data/disco\disco.00027.au
# ./data/disco\disco.00028.au
# ./data/disco\disco.00029.au
# ./data/disco\disco.00030.au
# ./data/disco\disco.00031.au
# ./data/disco\disco.00032.au
# ./data/disco\disco.00033.au
# ./data/disco\disco.00034.au
# ./data/disco\disco.00035.au
# ./data/disco\disco.00036.au
# ./data/disco\disco.00037.au
# ./data/disco\disco.00038.au
# ./data/disco\disco.00039.au
# ./data/disco\disco.00040.au
# ./data/disco\disco.00041.au
# ./data/disco\disco.00042.au
# ./data/disco\disco.00043.au
# ./data/disco\disco.00044.au
# ./data/disco\disco.00045.au
# ./data/disco\disco.00046.au
# ./data/disco\disco.00047.au
# ./data/disco\disco.00048.au
# ./data/disco\disco.00049.au
# ./data/disco\disco.00050.au
# ./data/disco\disco.00051.au
# ./data/disco\disco.00052.au
# ./data/disco\disco.00053.au
# ./data/disco\disco.00054.au
# ./data/disco\disco.00055.au
# ./data/disco\disco.00056.au
# ./data/disco\disco.00057.au
# ./data/disco\disco.00058.au
# ./data/disco\disco.00059.au
# ./data/disco\disco.00060.au
# ./data/disco\disco.00061.au
# ./data/disco\disco.00062.au
# ./data/disco\disco.00063.au
# ./data/disco\disco.00064.au
# ./data/disco\disco.00065.au
# ./data/disco\disco.00066.au
# ./data/disco\disco.00067.au
# ./data/disco\disco.00068.au
# ./data/disco\disco.00069.au
# ./data/disco\disco.00070.au
# ./data/disco\disco.00071.au
# ./data/disco\disco.00072.au
# ./data/disco\disco.00073.au
# ./data/disco\disco.00074.au
# ./data/disco\disco.00075.au
# ./data/disco\disco.00076.au
# ./data/disco\disco.00077.au
# ./data/disco\disco.00078.au
# ./data/disco\disco.00079.au
# ./data/disco\disco.00080.au
# ./data/disco\disco.00081.au
# ./data/disco\disco.00082.au
# ./data/disco\disco.00083.au
# ./data/disco\disco.00084.au
# ./data/disco\disco.00085.au
# ./data/disco\disco.00086.au
# ./data/disco\disco.00087.au
# ./data/disco\disco.00088.au
# ./data/disco\disco.00089.au
# ./data/disco\disco.00090.au
# ./data/disco\disco.00091.au
# ./data/disco\disco.00092.au
# ./data/disco\disco.00093.au
# ./data/disco\disco.00094.au
# ./data/disco\disco.00095.au
# ./data/disco\disco.00096.au
# ./data/disco\disco.00097.au
# ./data/disco\disco.00098.au
# ./data/disco\disco.00099.au
# ./data/hiphop\hiphop.00000.au
# ./data/hiphop\hiphop.00001.au
# ./data/hiphop\hiphop.00002.au
# ./data/hiphop\hiphop.00003.au
# ./data/hiphop\hiphop.00004.au
# ./data/hiphop\hiphop.00005.au
# ./data/hiphop\hiphop.00006.au
# ./data/hiphop\hiphop.00007.au
# ./data/hiphop\hiphop.00008.au
# ./data/hiphop\hiphop.00009.au
# ./data/hiphop\hiphop.00010.au
# ./data/hiphop\hiphop.00011.au
# ./data/hiphop\hiphop.00012.au
# ./data/hiphop\hiphop.00013.au
# ./data/hiphop\hiphop.00014.au
# ./data/hiphop\hiphop.00015.au
# ./data/hiphop\hiphop.00016.au
# ./data/hiphop\hiphop.00017.au
# ./data/hiphop\hiphop.00018.au
# ./data/hiphop\hiphop.00019.au
# ./data/hiphop\hiphop.00020.au
# ./data/hiphop\hiphop.00021.au
# ./data/hiphop\hiphop.00022.au
# ./data/hiphop\hiphop.00023.au
# ./data/hiphop\hiphop.00024.au
# ./data/hiphop\hiphop.00025.au
# ./data/hiphop\hiphop.00026.au
# ./data/hiphop\hiphop.00027.au
# ./data/hiphop\hiphop.00028.au
# ./data/hiphop\hiphop.00029.au
# ./data/hiphop\hiphop.00030.au
# ./data/hiphop\hiphop.00031.au
# ./data/hiphop\hiphop.00032.au
# ./data/hiphop\hiphop.00033.au
# ./data/hiphop\hiphop.00034.au
# ./data/hiphop\hiphop.00035.au
# ./data/hiphop\hiphop.00036.au
# ./data/hiphop\hiphop.00037.au
# ./data/hiphop\hiphop.00038.au
# ./data/hiphop\hiphop.00039.au
# ./data/hiphop\hiphop.00040.au
# ./data/hiphop\hiphop.00041.au
# ./data/hiphop\hiphop.00042.au
# ./data/hiphop\hiphop.00043.au
# ./data/hiphop\hiphop.00044.au
# ./data/hiphop\hiphop.00045.au
# ./data/hiphop\hiphop.00046.au
# ./data/hiphop\hiphop.00047.au
# ./data/hiphop\hiphop.00048.au
# ./data/hiphop\hiphop.00049.au
# ./data/hiphop\hiphop.00050.au
# ./data/hiphop\hiphop.00051.au
# ./data/hiphop\hiphop.00052.au
# ./data/hiphop\hiphop.00053.au
# ./data/hiphop\hiphop.00054.au
# ./data/hiphop\hiphop.00055.au
# ./data/hiphop\hiphop.00056.au
# ./data/hiphop\hiphop.00057.au
# ./data/hiphop\hiphop.00058.au
# ./data/hiphop\hiphop.00059.au
# ./data/hiphop\hiphop.00060.au
# ./data/hiphop\hiphop.00061.au
# ./data/hiphop\hiphop.00062.au
# ./data/hiphop\hiphop.00063.au
# ./data/hiphop\hiphop.00064.au
# ./data/hiphop\hiphop.00065.au
# ./data/hiphop\hiphop.00066.au
# ./data/hiphop\hiphop.00067.au
# ./data/hiphop\hiphop.00068.au
# ./data/hiphop\hiphop.00069.au
# ./data/hiphop\hiphop.00070.au
# ./data/hiphop\hiphop.00071.au
# ./data/hiphop\hiphop.00072.au
# ./data/hiphop\hiphop.00073.au
# ./data/hiphop\hiphop.00074.au
# ./data/hiphop\hiphop.00075.au
# ./data/hiphop\hiphop.00076.au
# ./data/hiphop\hiphop.00077.au
# ./data/hiphop\hiphop.00078.au
# ./data/hiphop\hiphop.00079.au
# ./data/hiphop\hiphop.00080.au
# ./data/hiphop\hiphop.00081.au
# ./data/hiphop\hiphop.00082.au
# ./data/hiphop\hiphop.00083.au
# ./data/hiphop\hiphop.00084.au
# ./data/hiphop\hiphop.00085.au
# ./data/hiphop\hiphop.00086.au
# ./data/hiphop\hiphop.00087.au
# ./data/hiphop\hiphop.00088.au
# ./data/hiphop\hiphop.00089.au
# ./data/hiphop\hiphop.00090.au
# ./data/hiphop\hiphop.00091.au
# ./data/hiphop\hiphop.00092.au
# ./data/hiphop\hiphop.00093.au
# ./data/hiphop\hiphop.00094.au
# ./data/hiphop\hiphop.00095.au
# ./data/hiphop\hiphop.00096.au
# ./data/hiphop\hiphop.00097.au
# ./data/hiphop\hiphop.00098.au
# ./data/hiphop\hiphop.00099.au
# ./data/jazz\jazz.00000.au
# ./data/jazz\jazz.00001.au
# ./data/jazz\jazz.00002.au
# ./data/jazz\jazz.00003.au
# ./data/jazz\jazz.00004.au
# ./data/jazz\jazz.00005.au
# ./data/jazz\jazz.00006.au
# ./data/jazz\jazz.00007.au
# ./data/jazz\jazz.00008.au
# ./data/jazz\jazz.00009.au
# ./data/jazz\jazz.00010.au
# ./data/jazz\jazz.00011.au
# ./data/jazz\jazz.00012.au
# ./data/jazz\jazz.00013.au
# ./data/jazz\jazz.00014.au
# ./data/jazz\jazz.00015.au
# ./data/jazz\jazz.00016.au
# ./data/jazz\jazz.00017.au
# ./data/jazz\jazz.00018.au
# ./data/jazz\jazz.00019.au
# ./data/jazz\jazz.00020.au
# ./data/jazz\jazz.00021.au
# ./data/jazz\jazz.00022.au
# ./data/jazz\jazz.00023.au
# ./data/jazz\jazz.00024.au
# ./data/jazz\jazz.00025.au
# ./data/jazz\jazz.00026.au
# ./data/jazz\jazz.00027.au
# ./data/jazz\jazz.00028.au
# ./data/jazz\jazz.00029.au
# ./data/jazz\jazz.00030.au
# ./data/jazz\jazz.00031.au
# ./data/jazz\jazz.00032.au
# ./data/jazz\jazz.00033.au
# ./data/jazz\jazz.00034.au
# ./data/jazz\jazz.00035.au
# ./data/jazz\jazz.00036.au
# ./data/jazz\jazz.00037.au
# ./data/jazz\jazz.00038.au
# ./data/jazz\jazz.00039.au
# ./data/jazz\jazz.00040.au
# ./data/jazz\jazz.00041.au
# ./data/jazz\jazz.00042.au
# ./data/jazz\jazz.00043.au
# ./data/jazz\jazz.00044.au
# ./data/jazz\jazz.00045.au
# ./data/jazz\jazz.00046.au
# ./data/jazz\jazz.00047.au
# ./data/jazz\jazz.00048.au
# ./data/jazz\jazz.00049.au
# ./data/jazz\jazz.00050.au
# ./data/jazz\jazz.00051.au
# ./data/jazz\jazz.00052.au
# ./data/jazz\jazz.00053.au
# ./data/jazz\jazz.00054.au
# ./data/jazz\jazz.00055.au
# ./data/jazz\jazz.00056.au
# ./data/jazz\jazz.00057.au
# ./data/jazz\jazz.00058.au
# ./data/jazz\jazz.00059.au
# ./data/jazz\jazz.00060.au
# ./data/jazz\jazz.00061.au
# ./data/jazz\jazz.00062.au
# ./data/jazz\jazz.00063.au
# ./data/jazz\jazz.00064.au
# ./data/jazz\jazz.00065.au
# ./data/jazz\jazz.00066.au
# ./data/jazz\jazz.00067.au
# ./data/jazz\jazz.00068.au
# ./data/jazz\jazz.00069.au
# ./data/jazz\jazz.00070.au
# ./data/jazz\jazz.00071.au
# ./data/jazz\jazz.00072.au
# ./data/jazz\jazz.00073.au
# ./data/jazz\jazz.00074.au
# ./data/jazz\jazz.00075.au
# ./data/jazz\jazz.00076.au
# ./data/jazz\jazz.00077.au
# ./data/jazz\jazz.00078.au
# ./data/jazz\jazz.00079.au
# ./data/jazz\jazz.00080.au
# ./data/jazz\jazz.00081.au
# ./data/jazz\jazz.00082.au
# ./data/jazz\jazz.00083.au
# ./data/jazz\jazz.00084.au
# ./data/jazz\jazz.00085.au
# ./data/jazz\jazz.00086.au
# ./data/jazz\jazz.00087.au
# ./data/jazz\jazz.00088.au
# ./data/jazz\jazz.00089.au
# ./data/jazz\jazz.00090.au
# ./data/jazz\jazz.00091.au
# ./data/jazz\jazz.00092.au
# ./data/jazz\jazz.00093.au
# ./data/jazz\jazz.00094.au
# ./data/jazz\jazz.00095.au
# ./data/jazz\jazz.00096.au
# ./data/jazz\jazz.00097.au
# ./data/jazz\jazz.00098.au
# ./data/jazz\jazz.00099.au
# ./data/metal\metal.00000.au
# ./data/metal\metal.00001.au
# ./data/metal\metal.00002.au
# ./data/metal\metal.00003.au
# ./data/metal\metal.00004.au
# ./data/metal\metal.00005.au
# ./data/metal\metal.00006.au
# ./data/metal\metal.00007.au
# ./data/metal\metal.00008.au
# ./data/metal\metal.00009.au
# ./data/metal\metal.00010.au
# ./data/metal\metal.00011.au
# ./data/metal\metal.00012.au
# ./data/metal\metal.00013.au
# ./data/metal\metal.00014.au
# ./data/metal\metal.00015.au
# ./data/metal\metal.00016.au
# ./data/metal\metal.00017.au
# ./data/metal\metal.00018.au
# ./data/metal\metal.00019.au
# ./data/metal\metal.00020.au
# ./data/metal\metal.00021.au
# ./data/metal\metal.00022.au
# ./data/metal\metal.00023.au
# ./data/metal\metal.00024.au
# ./data/metal\metal.00025.au
# ./data/metal\metal.00026.au
# ./data/metal\metal.00027.au
# ./data/metal\metal.00028.au
# ./data/metal\metal.00029.au
# ./data/metal\metal.00030.au
# ./data/metal\metal.00031.au
# ./data/metal\metal.00032.au
# ./data/metal\metal.00033.au
# ./data/metal\metal.00034.au
# ./data/metal\metal.00035.au
# ./data/metal\metal.00036.au
# ./data/metal\metal.00037.au
# ./data/metal\metal.00038.au
# ./data/metal\metal.00039.au
# ./data/metal\metal.00040.au
# ./data/metal\metal.00041.au
# ./data/metal\metal.00042.au
# ./data/metal\metal.00043.au
# ./data/metal\metal.00044.au
# ./data/metal\metal.00045.au
# ./data/metal\metal.00046.au
# ./data/metal\metal.00047.au
# ./data/metal\metal.00048.au
# ./data/metal\metal.00049.au
# ./data/metal\metal.00050.au
# ./data/metal\metal.00051.au
# ./data/metal\metal.00052.au
# ./data/metal\metal.00053.au
# ./data/metal\metal.00054.au
# ./data/metal\metal.00055.au
# ./data/metal\metal.00056.au
# ./data/metal\metal.00057.au
# ./data/metal\metal.00058.au
# ./data/metal\metal.00059.au
# ./data/metal\metal.00060.au
# ./data/metal\metal.00061.au
# ./data/metal\metal.00062.au
# ./data/metal\metal.00063.au
# ./data/metal\metal.00064.au
# ./data/metal\metal.00065.au
# ./data/metal\metal.00066.au
# ./data/metal\metal.00067.au
# ./data/metal\metal.00068.au
# ./data/metal\metal.00069.au
# ./data/metal\metal.00070.au
# ./data/metal\metal.00071.au
# ./data/metal\metal.00072.au
# ./data/metal\metal.00073.au
# ./data/metal\metal.00074.au
# ./data/metal\metal.00075.au
# ./data/metal\metal.00076.au
# ./data/metal\metal.00077.au
# ./data/metal\metal.00078.au
# ./data/metal\metal.00079.au
# ./data/metal\metal.00080.au
# ./data/metal\metal.00081.au
# ./data/metal\metal.00082.au
# ./data/metal\metal.00083.au
# ./data/metal\metal.00084.au
# ./data/metal\metal.00085.au
# ./data/metal\metal.00086.au
# ./data/metal\metal.00087.au
# ./data/metal\metal.00088.au
# ./data/metal\metal.00089.au
# ./data/metal\metal.00090.au
# ./data/metal\metal.00091.au
# ./data/metal\metal.00092.au
# ./data/metal\metal.00093.au
# ./data/metal\metal.00094.au
# ./data/metal\metal.00095.au
# ./data/metal\metal.00096.au
# ./data/metal\metal.00097.au
# ./data/metal\metal.00098.au
# ./data/metal\metal.00099.au
# ./data/pop\pop.00000.au
# ./data/pop\pop.00001.au
# ./data/pop\pop.00002.au
# ./data/pop\pop.00003.au
# ./data/pop\pop.00004.au
# ./data/pop\pop.00005.au
# ./data/pop\pop.00006.au
# ./data/pop\pop.00007.au
# ./data/pop\pop.00008.au
# ./data/pop\pop.00009.au
# ./data/pop\pop.00010.au
# ./data/pop\pop.00011.au
# ./data/pop\pop.00012.au
# ./data/pop\pop.00013.au
# ./data/pop\pop.00014.au
# ./data/pop\pop.00015.au
# ./data/pop\pop.00016.au
# ./data/pop\pop.00017.au
# ./data/pop\pop.00018.au
# ./data/pop\pop.00019.au
# ./data/pop\pop.00020.au
# ./data/pop\pop.00021.au
# ./data/pop\pop.00022.au
# ./data/pop\pop.00023.au
# ./data/pop\pop.00024.au
# ./data/pop\pop.00025.au
# ./data/pop\pop.00026.au
# ./data/pop\pop.00027.au
# ./data/pop\pop.00028.au
# ./data/pop\pop.00029.au
# ./data/pop\pop.00030.au
# ./data/pop\pop.00031.au
# ./data/pop\pop.00032.au
# ./data/pop\pop.00033.au
# ./data/pop\pop.00034.au
# ./data/pop\pop.00035.au
# ./data/pop\pop.00036.au
# ./data/pop\pop.00037.au
# ./data/pop\pop.00038.au
# ./data/pop\pop.00039.au
# ./data/pop\pop.00040.au
# ./data/pop\pop.00041.au
# ./data/pop\pop.00042.au
# ./data/pop\pop.00043.au
# ./data/pop\pop.00044.au
# ./data/pop\pop.00045.au
# ./data/pop\pop.00046.au
# ./data/pop\pop.00047.au
# ./data/pop\pop.00048.au
# ./data/pop\pop.00049.au
# ./data/pop\pop.00050.au
# ./data/pop\pop.00051.au
# ./data/pop\pop.00052.au
# ./data/pop\pop.00053.au
# ./data/pop\pop.00054.au
# ./data/pop\pop.00055.au
# ./data/pop\pop.00056.au
# ./data/pop\pop.00057.au
# ./data/pop\pop.00058.au
# ./data/pop\pop.00059.au
# ./data/pop\pop.00060.au
# ./data/pop\pop.00061.au
# ./data/pop\pop.00062.au
# ./data/pop\pop.00063.au
# ./data/pop\pop.00064.au
# ./data/pop\pop.00065.au
# ./data/pop\pop.00066.au
# ./data/pop\pop.00067.au
# ./data/pop\pop.00068.au
# ./data/pop\pop.00069.au
# ./data/pop\pop.00070.au
# ./data/pop\pop.00071.au
# ./data/pop\pop.00072.au
# ./data/pop\pop.00073.au
# ./data/pop\pop.00074.au
# ./data/pop\pop.00075.au
# ./data/pop\pop.00076.au
# ./data/pop\pop.00077.au
# ./data/pop\pop.00078.au
# ./data/pop\pop.00079.au
# ./data/pop\pop.00080.au
# ./data/pop\pop.00081.au
# ./data/pop\pop.00082.au
# ./data/pop\pop.00083.au
# ./data/pop\pop.00084.au
# ./data/pop\pop.00085.au
# ./data/pop\pop.00086.au
# ./data/pop\pop.00087.au
# ./data/pop\pop.00088.au
# ./data/pop\pop.00089.au
# ./data/pop\pop.00090.au
# ./data/pop\pop.00091.au
# ./data/pop\pop.00092.au
# ./data/pop\pop.00093.au
# ./data/pop\pop.00094.au
# ./data/pop\pop.00095.au
# ./data/pop\pop.00096.au
# ./data/pop\pop.00097.au
# ./data/pop\pop.00098.au
# ./data/pop\pop.00099.au
# ./data/reggae\reggae.00000.au
# ./data/reggae\reggae.00001.au
# ./data/reggae\reggae.00002.au
# ./data/reggae\reggae.00003.au
# ./data/reggae\reggae.00004.au
# ./data/reggae\reggae.00005.au
# ./data/reggae\reggae.00006.au
# ./data/reggae\reggae.00007.au
# ./data/reggae\reggae.00008.au
# ./data/reggae\reggae.00009.au
# ./data/reggae\reggae.00010.au
# ./data/reggae\reggae.00011.au
# ./data/reggae\reggae.00012.au
# ./data/reggae\reggae.00013.au
# ./data/reggae\reggae.00014.au
# ./data/reggae\reggae.00015.au
# ./data/reggae\reggae.00016.au
# ./data/reggae\reggae.00017.au
# ./data/reggae\reggae.00018.au
# ./data/reggae\reggae.00019.au
# ./data/reggae\reggae.00020.au
# ./data/reggae\reggae.00021.au
# ./data/reggae\reggae.00022.au
# ./data/reggae\reggae.00023.au
# ./data/reggae\reggae.00024.au
# ./data/reggae\reggae.00025.au
# ./data/reggae\reggae.00026.au
# ./data/reggae\reggae.00027.au
# ./data/reggae\reggae.00028.au
# ./data/reggae\reggae.00029.au
# ./data/reggae\reggae.00030.au
# ./data/reggae\reggae.00031.au
# ./data/reggae\reggae.00032.au
# ./data/reggae\reggae.00033.au
# ./data/reggae\reggae.00034.au
# ./data/reggae\reggae.00035.au
# ./data/reggae\reggae.00036.au
# ./data/reggae\reggae.00037.au
# ./data/reggae\reggae.00038.au
# ./data/reggae\reggae.00039.au
# ./data/reggae\reggae.00040.au
# ./data/reggae\reggae.00041.au
# ./data/reggae\reggae.00042.au
# ./data/reggae\reggae.00043.au
# ./data/reggae\reggae.00044.au
# ./data/reggae\reggae.00045.au
# ./data/reggae\reggae.00046.au
# ./data/reggae\reggae.00047.au
# ./data/reggae\reggae.00048.au
# ./data/reggae\reggae.00049.au
# ./data/reggae\reggae.00050.au
# ./data/reggae\reggae.00051.au
# ./data/reggae\reggae.00052.au
# ./data/reggae\reggae.00053.au
# ./data/reggae\reggae.00054.au
# ./data/reggae\reggae.00055.au
# ./data/reggae\reggae.00056.au
# ./data/reggae\reggae.00057.au
# ./data/reggae\reggae.00058.au
# ./data/reggae\reggae.00059.au
# ./data/reggae\reggae.00060.au
# ./data/reggae\reggae.00061.au
# ./data/reggae\reggae.00062.au
# ./data/reggae\reggae.00063.au
# ./data/reggae\reggae.00064.au
# ./data/reggae\reggae.00065.au
# ./data/reggae\reggae.00066.au
# ./data/reggae\reggae.00067.au
# ./data/reggae\reggae.00068.au
# ./data/reggae\reggae.00069.au
# ./data/reggae\reggae.00070.au
# ./data/reggae\reggae.00071.au
# ./data/reggae\reggae.00072.au
# ./data/reggae\reggae.00073.au
# ./data/reggae\reggae.00074.au
# ./data/reggae\reggae.00075.au
# ./data/reggae\reggae.00076.au
# ./data/reggae\reggae.00077.au
# ./data/reggae\reggae.00078.au
# ./data/reggae\reggae.00079.au
# ./data/reggae\reggae.00080.au
# ./data/reggae\reggae.00081.au
# ./data/reggae\reggae.00082.au
# ./data/reggae\reggae.00083.au
# ./data/reggae\reggae.00084.au
# ./data/reggae\reggae.00085.au
# ./data/reggae\reggae.00086.au
# ./data/reggae\reggae.00087.au
# ./data/reggae\reggae.00088.au
# ./data/reggae\reggae.00089.au
# ./data/reggae\reggae.00090.au
# ./data/reggae\reggae.00091.au
# ./data/reggae\reggae.00092.au
# ./data/reggae\reggae.00093.au
# ./data/reggae\reggae.00094.au
# ./data/reggae\reggae.00095.au
# ./data/reggae\reggae.00096.au
# ./data/reggae\reggae.00097.au
# ./data/reggae\reggae.00098.au
# ./data/reggae\reggae.00099.au
# ./data/rock\rock.00000.au
# ./data/rock\rock.00001.au
# ./data/rock\rock.00002.au
# ./data/rock\rock.00003.au
# ./data/rock\rock.00004.au
# ./data/rock\rock.00005.au
# ./data/rock\rock.00006.au
# ./data/rock\rock.00007.au
# ./data/rock\rock.00008.au
# ./data/rock\rock.00009.au
# ./data/rock\rock.00010.au
# ./data/rock\rock.00011.au
# ./data/rock\rock.00012.au
# ./data/rock\rock.00013.au
# ./data/rock\rock.00014.au
# ./data/rock\rock.00015.au
# ./data/rock\rock.00016.au
# ./data/rock\rock.00017.au
# ./data/rock\rock.00018.au
# ./data/rock\rock.00019.au
# ./data/rock\rock.00020.au
# ./data/rock\rock.00021.au
# ./data/rock\rock.00022.au
# ./data/rock\rock.00023.au
# ./data/rock\rock.00024.au
# ./data/rock\rock.00025.au
# ./data/rock\rock.00026.au
# ./data/rock\rock.00027.au
# ./data/rock\rock.00028.au
# ./data/rock\rock.00029.au
# ./data/rock\rock.00030.au
# ./data/rock\rock.00031.au
# ./data/rock\rock.00032.au
# ./data/rock\rock.00033.au
# ./data/rock\rock.00034.au
# ./data/rock\rock.00035.au
# ./data/rock\rock.00036.au
# ./data/rock\rock.00037.au
# ./data/rock\rock.00038.au
# ./data/rock\rock.00039.au
# ./data/rock\rock.00040.au
# ./data/rock\rock.00041.au
# ./data/rock\rock.00042.au
# ./data/rock\rock.00043.au
# ./data/rock\rock.00044.au
# ./data/rock\rock.00045.au
# ./data/rock\rock.00046.au
# ./data/rock\rock.00047.au
# ./data/rock\rock.00048.au
# ./data/rock\rock.00049.au
# ./data/rock\rock.00050.au
# ./data/rock\rock.00051.au
# ./data/rock\rock.00052.au
# ./data/rock\rock.00053.au
# ./data/rock\rock.00054.au
# ./data/rock\rock.00055.au
# ./data/rock\rock.00056.au
# ./data/rock\rock.00057.au
# ./data/rock\rock.00058.au
# ./data/rock\rock.00059.au
# ./data/rock\rock.00060.au
# ./data/rock\rock.00061.au
# ./data/rock\rock.00062.au
# ./data/rock\rock.00063.au
# ./data/rock\rock.00064.au
# ./data/rock\rock.00065.au
# ./data/rock\rock.00066.au
# ./data/rock\rock.00067.au
# ./data/rock\rock.00068.au
# ./data/rock\rock.00069.au
# ./data/rock\rock.00070.au
# ./data/rock\rock.00071.au
# ./data/rock\rock.00072.au
# ./data/rock\rock.00073.au
# ./data/rock\rock.00074.au
# ./data/rock\rock.00075.au
# ./data/rock\rock.00076.au
# ./data/rock\rock.00077.au
# ./data/rock\rock.00078.au
# ./data/rock\rock.00079.au
# ./data/rock\rock.00080.au
# ./data/rock\rock.00081.au
# ./data/rock\rock.00082.au
# ./data/rock\rock.00083.au
# ./data/rock\rock.00084.au
# ./data/rock\rock.00085.au
# ./data/rock\rock.00086.au
# ./data/rock\rock.00087.au
# ./data/rock\rock.00088.au
# ./data/rock\rock.00089.au
# ./data/rock\rock.00090.au
# ./data/rock\rock.00091.au
# ./data/rock\rock.00092.au
# ./data/rock\rock.00093.au
# ./data/rock\rock.00094.au
# ./data/rock\rock.00095.au
# ./data/rock\rock.00096.au
# ./data/rock\rock.00097.au
# ./data/rock\rock.00098.au
# ./data/rock\rock.00099.au

# %%
# create a list of all features

features = 'filename chroma_stft_mean chroma_stft_var spectral_centroid_mean spectral_centroid_var spectral_bandwidth_mean spectral_bandwidth_var rolloff_mean rolloff_var zero_crossing_rate_mean zero_crossing_rate_var tempo' 
for i in range(1, 21):
    features += f' mfcc{i}_mean'
    features += f' mfcc{i}_var'
    
features += ' genre'
features = features.split()

# create an empty dataframe
dfFeatures = pd.DataFrame(columns = features)
dfFeatures
# Out:
# Empty DataFrame
# Columns: [filename, chroma_stft_mean, chroma_stft_var, spectral_centroid_mean, spectral_centroid_var, spectral_bandwidth_mean, spectral_bandwidth_var, rolloff_mean, rolloff_var, zero_crossing_rate_mean, zero_crossing_rate_var, tempo, mfcc1_mean, mfcc1_var, mfcc2_mean, mfcc2_var, mfcc3_mean, mfcc3_var, mfcc4_mean, mfcc4_var, mfcc5_mean, mfcc5_var, mfcc6_mean, mfcc6_var, mfcc7_mean, mfcc7_var, mfcc8_mean, mfcc8_var, mfcc9_mean, mfcc9_var, mfcc10_mean, mfcc10_var, mfcc11_mean, mfcc11_var, mfcc12_mean, mfcc12_var, mfcc13_mean, mfcc13_var, mfcc14_mean, mfcc14_var, mfcc15_mean, mfcc15_var, mfcc16_mean, mfcc16_var, mfcc17_mean, mfcc17_var, mfcc18_mean, mfcc18_var, mfcc19_mean, mfcc19_var, mfcc20_mean, mfcc20_var, genre]
# Index: []
#
# [0 rows x 53 columns]

# %%
# load audio time series into a list using librosa.load, create list of corresponding labels
for genre in genres:
    # identify the path using the genre
    path = './data/' + genre
    # loop through every file in the path
    for file in os.listdir(path):
        filename = path + '/' + file
        
        # load time series and sampling rate
        y, sr = librosa.load(filename, mono = True, duration = 10)
        
        # extract all features from time series and sampling rate
        chromaStft = librosa.feature.chroma_stft(y=y, sr=sr)
        specCent = librosa.feature.spectral_centroid(y=y, sr=sr)
        specBandwidth = librosa.feature.spectral_bandwidth(y=y, sr=sr)
        rolloff = librosa.feature.spectral_rolloff(y=y, sr=sr)
        zeroCrossing = librosa.feature.zero_crossing_rate(y)
        mfcc = librosa.feature.mfcc(y=y, sr=sr)
        tempo = librosa.beat.tempo(y=y, sr=sr)
        
        # personal check to make sure we dont get dynamic tempo
        if len(tempo) != 1:
            raise ValueError("Dynamic tempo was returned.")
        
        # dictionary to upload current row
        uploadDict = {}
        uploadDict['filename'] = file
        uploadDict['genre'] = genre
        
        # get the mean of all the mfcc
        mfccMeans = []
        for index, value in enumerate(mfcc):
            currMfccMean = f'mfcc{index+1}_mean'
            currMfccVar = f'mfcc{index+1}_var'
            mfccMean = np.mean(value)
            mfccVar = np.var(value)
            uploadDict[currMfccMean] = mfccMean
            uploadDict[currMfccVar] = mfccVar
            

        # get the means and add to dict
        uploadDict['chroma_stft_mean'] = np.mean(chromaStft)
        uploadDict['chroma_stft_var'] = np.var(chromaStft)
        uploadDict['spectral_centroid_mean'] = np.mean(specCent)
        uploadDict['spectral_centroid_var'] = np.var(specCent)
        uploadDict['spectral_bandwidth_mean'] = np.mean(specBandwidth)
        uploadDict['spectral_bandwidth_var'] = np.var(specBandwidth)
        uploadDict['rolloff_mean'] = np.mean(rolloff)
        uploadDict['rolloff_var'] = np.var(rolloff)
        uploadDict['zero_crossing_rate_mean'] = np.mean(zeroCrossing)
        uploadDict['zero_crossing_rate_var'] = np.var(zeroCrossing)
        uploadDict['tempo'] = tempo[0]
        
        # append all values to dataframe
        dfFeatures = dfFeatures.append(uploadDict, ignore_index = True)
            
            
            
        
dfFeatures.head()
# Out:
#          filename  chroma_stft_mean  chroma_stft_var  spectral_centroid_mean  \
# 0  blues.00000.au          0.342053         0.089037             1782.622682
# 1  blues.00001.au          0.358000         0.090658             1364.273766
# 2  blues.00002.au          0.382027         0.087238             1521.556846
# 3  blues.00003.au          0.391765         0.094778              947.018874
# 4  blues.00004.au          0.316456         0.090731             2046.427867
#
#    spectral_centroid_var  spectral_bandwidth_mean  spectral_bandwidth_var  \
# 0          116977.082472              2020.556328            84328.680518
# 1          291346.764439              1842.030467           221553.848927
# 2          224961.620877              1736.799388            64062.188124
# 3          135762.858041              1427.836298           122599.100317
# 4          540932.742010              1858.463045           111903.623326
#
#    rolloff_mean   rolloff_var  zero_crossing_rate_mean  ...  mfcc16_var  \
# 0   3845.075667  8.328459e+05                 0.080111  ...   69.972038
# 1   2976.303348  2.452152e+06                 0.055211  ...   62.798424
# 2   3028.062974  8.508550e+05                 0.070182  ...   37.905025
# 3   1863.946038  9.467861e+05                 0.030092  ...   33.782215
# 4   4005.025898  2.115368e+06                 0.116385  ...  129.746536
#
#    mfcc17_mean  mfcc17_var  mfcc18_mean  mfcc18_var  mfcc19_mean  mfcc19_var  \
# 0    -2.870996   35.479565     0.306077   43.506840    -2.700369   58.693989
# 1     0.497853   61.236259     0.039326   48.482971    -1.083576   54.454639
# 2    -6.660074   53.707203    -2.039234   48.657555    -2.045270   45.731483
# 3     0.231585   31.175877     2.437521   30.588255     1.284240   26.782133
# 4    -8.198335   71.464584    -1.059961   62.674892    -3.900608   59.124683
#
#    mfcc20_mean  mfcc20_var  genre
# 0     2.370232   48.047718  blues
# 1    -0.112309   53.948948  blues
# 2    -2.697336   28.559635  blues
# 3    -2.200283   31.076508  blues
# 4   -12.995133   57.077927  blues
#
# [5 rows x 53 columns]

# %%
dfFeatures.to_csv('music_features_updated.csv', index = False)
